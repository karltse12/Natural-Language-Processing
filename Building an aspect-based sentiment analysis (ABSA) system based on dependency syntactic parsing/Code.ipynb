# %% [markdown]
# #  1. Data Loading and Text Preprocessing

# %% [markdown]
# ## 1.1 Data Loading and Preprocessing

# %% [markdown]
# #### 1.1.1 Import Libraries

# %%
import xmltodict
import nltk
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize
# !pip install TextBlob
from textblob import TextBlob
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\manho\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# function to remove stopwords
def remove_stopwords(text):
    text_token= [word for word in word_tokenize(text) if not word in Stopwords]
    text = ' '.join(text_token)
    return text

# %% [markdown]
# #### 1.1.2 Data Loading and Exploring

# %%
with open("Restaurants.xml") as fd:
    doc = xmltodict.parse(fd.read())

# %%
doc = doc['sentences']
doc
# Out:
# OrderedDict([('sentence',
#               [OrderedDict([('@id', '3121'),
#                             ('text', 'But the staff was so horrible to us.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'staff'),
#                                                         ('@polarity',
#                                                          'negative'),
#                                                         ('@from', '8'),
#                                                         ('@to', '13')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'service'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '2777'),
#                             ('text',
#                              "To be completely fair, the only redeeming factor was the food, which was above average, but couldn't make up for all the other deficiencies of Teodora."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'food'),
#                                                         ('@polarity',
#                                                          'positive'),
#                                                         ('@from', '57'),
#                                                         ('@to', '61')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'anecdotes/miscellaneous'),
#                                                          ('@polarity',
#                                                           'negative')])])]))]),
#                OrderedDict([('@id', '1634'),
#                             ('text',
#                              "The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '4'),
#                                                          ('@to', '8')]),
#                                             OrderedDict([('@term', 'kitchen'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '55'),
#                                                          ('@to', '62')]),
#                                             OrderedDict([('@term', 'menu'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '141'),
#                                                          ('@to', '145')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2534'),
#                             ('text',
#                              'Where Gabriela personaly greets you and recommends you what to eat.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'service'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '583'),
#                             ('text',
#                              "For those that go once and don't enjoy it, all I can say is that they just don't get it."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2846'),
#                             ('text',
#                              "Not only was the food outstanding, but the little 'perks' were great."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '17'),
#                                                          ('@to', '21')]),
#                                             OrderedDict([('@term', 'perks'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '51'),
#                                                          ('@to', '56')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '1571'),
#                             ('text',
#                              'It is very overpriced and not very tasty.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'negative')]),
#                                             OrderedDict([('@category',
#                                                           'price'),
#                                                          ('@polarity',
#                                                           'negative')])])]))]),
#                OrderedDict([('@id', '1458'),
#                             ('text',
#                              'Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term',
#                                                           'orrechiete with sausage and chicken'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '27'),
#                                                          ('@to', '62')]),
#                                             OrderedDict([('@term', 'waiters'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '76'),
#                                                          ('@to', '83')]),
#                                             OrderedDict([('@term', 'meats'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '152'),
#                                                          ('@to', '157')]),
#                                             OrderedDict([('@term', 'dish'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '113'),
#                                                          ('@to', '117')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '3161'),
#                             ('text',
#                              'The Bagels have an outstanding taste with a terrific texture, both chewy yet not gummy.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'Bagels'),
#                                                         ('@polarity',
#                                                          'positive'),
#                                                         ('@from', '4'),
#                                                         ('@to', '10')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2391'),
#                             ('text',
#                              'Nevertheless the food itself is pretty good.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'food'),
#                                                         ('@polarity',
#                                                          'positive'),
#                                                         ('@from', '17'),
#                                                         ('@to', '21')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '296'),
#                             ('text',
#                              'They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'toast'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '41'),
#                                                          ('@to', '46')]),
#                                             OrderedDict([('@term',
#                                                           'mayonnaise'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '18'),
#                                                          ('@to', '28')]),
#                                             OrderedDict([('@term', 'bacon'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '126'),
#                                                          ('@to', '131')]),
#                                             OrderedDict([('@term', 'cheese'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '73'),
#                                                          ('@to', '79')]),
#                                             OrderedDict([('@term',
#                                                           'ingredients'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '57'),
#                                                          ('@to', '68')]),
#                                             OrderedDict([('@term', 'plate'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '170'),
#                                                          ('@to', '175')]),
#                                             OrderedDict([('@term', 'omelet'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '86'),
#                                                          ('@to', '92')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '1793'),
#                             ('text',
#                              'It took half an hour to get our check, which was perfect since we could sit, have drinks and talk!'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'drinks'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '82'),
#                                                          ('@to', '88')]),
#                                             OrderedDict([('@term', 'check'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '32'),
#                                                          ('@to', '37')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'service'),
#                                                         ('@polarity',
#                                                          'conflict')]))]))]),
#                OrderedDict([('@id', '2200'),
#                             ('text',
#                              'The design and atmosphere is just as good.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'design'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '4'),
#                                                          ('@to', '10')]),
#                                             OrderedDict([('@term',
#                                                           'atmosphere'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '15'),
#                                                          ('@to', '25')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3195'),
#                             ('text',
#                              'He has visited Thailand and is quite expert on the cuisine.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'cuisine'),
#                                                         ('@polarity',
#                                                          'positive'),
#                                                         ('@from', '51'),
#                                                         ('@to', '58')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3119'),
#                             ('text',
#                              "I would definitely recommend Mary's and am making it one of my regular neighborhood haunts."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3359'),
#                             ('text',
#                              'The pizza is the best if you like thin crusted pizza.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'pizza'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '4'),
#                                                          ('@to', '9')]),
#                                             OrderedDict([('@term',
#                                                           'thin crusted pizza'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '34'),
#                                                          ('@to', '52')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '70'),
#                             ('text',
#                              'My Girlfriend and I stumbled onto this hopping place the other night and had a great time!'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1829'),
#                             ('text',
#                              "He can't help, they're bought up so fast."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '2935'),
#                             ('text',
#                              'Secondly, on this night the place was overwhelmed by upper east side ladies perfume.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '1805'),
#                             ('text',
#                              'i have eaten here a handful of times, for no reason besides sheer convenience.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '2559'),
#                             ('text', 'Obviously run by folks who know a pie.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'service'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '716'),
#                             ('text', 'We were very disappointed.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '2464'),
#                             ('text',
#                              'IT IS DEFINITELY SPECIAL AND AFFORDABLE.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category',
#                                                           'anecdotes/miscellaneous'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'price'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '385'),
#                             ('text', 'I really liked this place.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1350'),
#                             ('text', 'I will be going back very soon.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3534'),
#                             ('text',
#                              'All the money went into the interior decoration, none of it went to the chefs.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term',
#                                                           'interior decoration'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '28'),
#                                                          ('@to', '47')]),
#                                             OrderedDict([('@term', 'chefs'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '72'),
#                                                          ('@to', '77')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category',
#                                                           'ambience'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'negative')])])]))]),
#                OrderedDict([('@id', '1407'),
#                             ('text',
#                              'The seats are uncomfortable if you are sitting against the wall on wooden benches.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'seats'),
#                                                         ('@polarity',
#                                                          'negative'),
#                                                         ('@from', '4'),
#                                                         ('@to', '9')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '565'),
#                             ('text', 'I asked for seltzer with lime, no ice.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term',
#                                                          'seltzer with lime'),
#                                                         ('@polarity',
#                                                          'neutral'),
#                                                         ('@from', '12'),
#                                                         ('@to', '29')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '387'),
#                             ('text', 'It was pretty inexpensive too.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'price'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1314'),
#                             ('text', 'Will not be back.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '675'),
#                             ('text',
#                              "Don't go alone---even two people isn't enough for the whole experience, with pickles and a selection of meats and seafoods."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'pickles'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '77'),
#                                                          ('@to', '84')]),
#                                             OrderedDict([('@term',
#                                                           'selection of meats and seafoods'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '91'),
#                                                          ('@to', '122')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2227'),
#                             ('text',
#                              "My suggestion is to eat family style because you'll want to try the other dishes."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'dishes'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '74'),
#                                                          ('@to', '80')]),
#                                             OrderedDict([('@term',
#                                                           'eat family style'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '20'),
#                                                          ('@to', '36')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '3367'),
#                             ('text',
#                              'Best of all is the warm vibe, the owner is super friendly and service is fast.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'vibe'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '24'),
#                                                          ('@to', '28')]),
#                                             OrderedDict([('@term', 'owner'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '34'),
#                                                          ('@to', '39')]),
#                                             OrderedDict([('@term', 'service'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '62'),
#                                                          ('@to', '69')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'ambience'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '1210'),
#                             ('text', "This isn't a value joint."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'price'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '2191'),
#                             ('text',
#                              "Faan's got a great concept but a little rough on the delivery."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'delivery'),
#                                                         ('@polarity',
#                                                          'negative'),
#                                                         ('@from', '53'),
#                                                         ('@to', '61')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category',
#                                                           'anecdotes/miscellaneous'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'negative')])])]))]),
#                OrderedDict([('@id', '270'),
#                             ('text',
#                              "From the incredible food, to the warm atmosphere, to the friendly service, this downtown neighborhood spot doesn't miss a beat."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '20'),
#                                                          ('@to', '24')]),
#                                             OrderedDict([('@term',
#                                                           'atmosphere'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '38'),
#                                                          ('@to', '48')]),
#                                             OrderedDict([('@term', 'service'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '66'),
#                                                          ('@to', '73')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'ambience'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '638'),
#                             ('text',
#                              "Great food at REASONABLE prices, makes for an evening that can't be beat!"),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '6'),
#                                                          ('@to', '10')]),
#                                             OrderedDict([('@term', 'prices'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '25'),
#                                                          ('@to', '31')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'price'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '500'),
#                             ('text',
#                              'Look foward to trying the Ruben upon returning.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1108'),
#                             ('text',
#                              "The only other steakhouse that seems to hold a candle to Roth's is the Strip House."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '3294'),
#                             ('text',
#                              'We usually go to the Chart House to celebrate a birthday or anniversary.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '388'),
#                             ('text',
#                              'this little place has a cute interior decor and affordable city prices.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term',
#                                                           'interior decor'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '29'),
#                                                          ('@to', '43')]),
#                                             OrderedDict([('@term', 'prices'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '64'),
#                                                          ('@to', '70')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category',
#                                                           'ambience'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'price'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '3070'),
#                             ('text', "You'll adore it."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3373'),
#                             ('text', 'Two words: Free wine.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'wine'),
#                                                         ('@polarity',
#                                                          'positive'),
#                                                         ('@from', '16'),
#                                                         ('@to', '20')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'price'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '425'),
#                             ('text',
#                              'The price is reasonable although the service is poor.'),
#                             ('aspectTerms',
# ...
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'bar food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '28'),
#                                                          ('@to', '36')]),
#                                             OrderedDict([('@term', 'menu'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '60'),
#                                                          ('@to', '64')]),
#                                             OrderedDict([('@term',
#                                                           'hand-crafted beers'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '93'),
#                                                          ('@to', '111')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1475'),
#                             ('text', 'A big disappointment, all around.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '1560'),
#                             ('text', 'And its absolutely DELICIOUS.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2025'),
#                             ('text', 'No free drink.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'drink'),
#                                                         ('@polarity',
#                                                          'neutral'),
#                                                         ('@from', '8'),
#                                                         ('@to', '13')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'price'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '1760'),
#                             ('text',
#                              "I would say that all was fine and tasty but the heaviness on my stomach someting that i can't not mention or undermine."),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category', 'food'),
#                                                         ('@polarity',
#                                                          'conflict')]))]))]),
#                OrderedDict([('@id', '259'),
#                             ('text',
#                              'This is my first time writing a review for a restaurant because the food and service was excellent.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'food'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '68'),
#                                                          ('@to', '72')]),
#                                             OrderedDict([('@term', 'service'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '77'),
#                                                          ('@to', '84')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'service'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'anecdotes/miscellaneous'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '2829'),
#                             ('text', 'Definitely Highly NOT recommended.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'negative')]))]))]),
#                OrderedDict([('@id', '1211'),
#                             ('text',
#                              'While they keep the capex to a minimum, they do put some cash into the bagels, because they among the best in the city.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term', 'capex'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '20'),
#                                                          ('@to', '25')]),
#                                             OrderedDict([('@term', 'bagels'),
#                                                          ('@polarity',
#                                                           'neutral'),
#                                                          ('@from', '71'),
#                                                          ('@to', '77')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'positive')]),
#                                             OrderedDict([('@category',
#                                                           'price'),
#                                                          ('@polarity',
#                                                           'positive')])])]))]),
#                OrderedDict([('@id', '177'),
#                             ('text',
#                              'I had a huge group for my birthday and we were well taken care of.'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'service'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1312'),
#                             ('text',
#                              'The two star chefs left quite some time ago to open their own place.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'chefs'),
#                                                         ('@polarity',
#                                                          'neutral'),
#                                                         ('@from', '13'),
#                                                         ('@to', '18')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'neutral')]))]))]),
#                OrderedDict([('@id', '1565'),
#                             ('text', "Don't waste money on decor."),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'decor'),
#                                                         ('@polarity',
#                                                          'neutral'),
#                                                         ('@from', '21'),
#                                                         ('@to', '26')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '2959'),
#                             ('text',
#                              'They also have a back garden open in the summer - cute and French with outdoor seating - what more could you ask for?'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term',
#                                                           'back garden'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '17'),
#                                                          ('@to', '28')]),
#                                             OrderedDict([('@term',
#                                                           'outdoor seating'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '71'),
#                                                          ('@to', '86')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '3339'),
#                             ('text',
#                              'go to any corned indian restaurant, and the little india strip along east 6 st rules supreme!'),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'anecdotes/miscellaneous'),
#                                                         ('@polarity',
#                                                          'positive')]))]))]),
#                OrderedDict([('@id', '1659'),
#                             ('text',
#                              'I have never before eaten 40 pieces of relatively good nigiri.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            OrderedDict([('@term', 'nigiri'),
#                                                         ('@polarity',
#                                                          'neutral'),
#                                                         ('@from', '55'),
#                                                         ('@to', '61')]))])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            [OrderedDict([('@category', 'food'),
#                                                          ('@polarity',
#                                                           'neutral')]),
#                                             OrderedDict([('@category',
#                                                           'anecdotes/miscellaneous'),
#                                                          ('@polarity',
#                                                           'neutral')])])]))]),
#                OrderedDict([('@id', '839'),
#                             ('text',
#                              'Given the incredible architecture surrounding it, this place has no character.'),
#                             ('aspectTerms',
#                              OrderedDict([('aspectTerm',
#                                            [OrderedDict([('@term',
#                                                           'architecture'),
#                                                          ('@polarity',
#                                                           'positive'),
#                                                          ('@from', '21'),
#                                                          ('@to', '33')]),
#                                             OrderedDict([('@term', 'place'),
#                                                          ('@polarity',
#                                                           'negative'),
#                                                          ('@from', '55'),
#                                                          ('@to', '60')])])])),
#                             ('aspectCategories',
#                              OrderedDict([('aspectCategory',
#                                            OrderedDict([('@category',
#                                                          'ambience'),
#                                                         ('@polarity',
#                                                          'conflict')]))]))]),
#                ...])])

# %%
len(doc['sentence'])
# Out:
# 3041

# %% [markdown]
# #### 1.1.3 Data Preprocessing

# %%
# delete no aspect terms
for i in range(len(doc['sentence'])-1, 0, -1):
    if 'aspectTerms' not in doc['sentence'][i].keys():
        del doc['sentence'][i]

# %%
# create dictionary for holding necessary data
data_dict = {}
original_data_dict = {}
term_dict = {}
polarity_dict = {}
from_dict = {}
to_dict = {}

# %%
for i in range(len(doc['sentence'])):
    term_list = []
    polarity_list = []
    from_list = []
    to_list = []
    
    try:
            term_list.append(doc['sentence'][i]['aspectTerms']['aspectTerm']['@term'].lower()) # lower case for aspect terms
            polarity_list.append(doc['sentence'][i]['aspectTerms']['aspectTerm']['@polarity'])
            
    except:
        for j in range(len(doc['sentence'][i]['aspectTerms']['aspectTerm'])):
                term_list.append(doc['sentence'][i]['aspectTerms']['aspectTerm'][j]['@term'].lower()) # lower case for aspect terms
                polarity_list.append(doc['sentence'][i]['aspectTerms']['aspectTerm'][j]['@polarity'])

    term_dict[i] = term_list
    polarity_dict[i] = polarity_list

# %%
# create the dictionary that hold all data needed
for i in range(len(doc['sentence'])):
    data_dict[i] = {'id': doc['sentence'][i]['@id'], 
                    'text': doc['sentence'][i]['text'].lower(),
                    'term': term_dict[i],
                    'polarity': polarity_dict[i],
                    }
    
    original_data_dict[i] = {'id': doc['sentence'][i]['@id'], 
                'text': doc['sentence'][i]['text'].lower(),
                'term': term_dict[i],
                'polarity': polarity_dict[i],
                }

# %%
# combine aspect term with more than 1 word into one word in both sentence and aspect term
for i in range(len(data_dict)):
    for j in range(len(data_dict[i]['term'])):
        if len(data_dict[i]['term'][j].split())>1:
            old_term = data_dict[i]['term'][j]
            new_term = data_dict[i]['term'][j].replace(' ', '')
            data_dict[i]['term'][j] = new_term
            data_dict[i]['text'] = data_dict[i]['text'].replace(old_term, new_term)

# %%
from nltk.corpus import stopwords
Stopwords = stopwords.words("english")
Stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# remove neglet words in stopwords
Stopwords.remove('no')
Stopwords.remove('not')
Stopwords.remove('don\'t')
Stopwords.remove('aren\'t')
Stopwords.remove('couldn\'t')
Stopwords.remove('didn\'t')
Stopwords.remove('hadn\'t')
Stopwords.remove('hasn\'t')
Stopwords.remove('haven\'t')
Stopwords.remove('doesn\'t')
Stopwords.remove('isn\'t')
Stopwords.remove('mightn\'t')
Stopwords.remove('mustn\'t')     
Stopwords.remove('needn\'t') 
Stopwords.remove('shan\'t') 
Stopwords.remove('shouldn\'t')
Stopwords.remove('wasn\'t')
Stopwords.remove('weren\'t')
Stopwords.remove('won\'t')
Stopwords.remove('wouldn\'t')

# %%
# remove stopwords in sentence
for i in range(len(data_dict)):
    data_dict[i]['text'] = data_dict[i]['text'].lower()
    data_dict[i]['text'] = remove_stopwords(data_dict[i]['text'])

# %%
data_dict
# Out:
# {0: {'id': '3121',
#   'text': 'staff horrible us .',
#   'term': ['staff'],
#   'polarity': ['negative']},
#  1: {'id': '2777',
#   'text': "completely fair , redeeming factor food , average , could n't make deficiencies teodora .",
#   'term': ['food'],
#   'polarity': ['positive']},
#  2: {'id': '1634',
#   'text': "food uniformly exceptional , capable kitchen proudly whip whatever feel like eating , whether 's menu not .",
#   'term': ['food', 'kitchen', 'menu'],
#   'polarity': ['positive', 'positive', 'neutral']},
#  3: {'id': '2846',
#   'text': "not food outstanding , little 'perks ' great .",
#   'term': ['food', 'perks'],
#   'polarity': ['positive', 'positive']},
#  4: {'id': '1458',
#   'text': 'agreed favorite orrechietewithsausageandchicken ( usually waiters kind enough split dish half get sample meats ) .',
#   'term': ['orrechietewithsausageandchicken', 'waiters', 'meats', 'dish'],
#   'polarity': ['positive', 'positive', 'neutral', 'neutral']},
#  5: {'id': '3161',
#   'text': 'bagels outstanding taste terrific texture , chewy yet not gummy .',
#   'term': ['bagels'],
#   'polarity': ['positive']},
#  6: {'id': '2391',
#   'text': 'nevertheless food pretty good .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  7: {'id': '296',
#   'text': 'not mayonnaise , forgot toast , left ingredients ( ie cheese omelet ) , hot temperatures bacon cooked crumbled plate touched .',
#   'term': ['toast',
#    'mayonnaise',
#    'bacon',
#    'cheese',
#    'ingredients',
#    'plate',
#    'omelet'],
#   'polarity': ['negative',
#    'negative',
#    'negative',
#    'neutral',
#    'negative',
#    'neutral',
#    'neutral']},
#  8: {'id': '1793',
#   'text': 'took half hour get check , perfect since could sit , drinks talk !',
#   'term': ['drinks', 'check'],
#   'polarity': ['neutral', 'neutral']},
#  9: {'id': '2200',
#   'text': 'design atmosphere good .',
#   'term': ['design', 'atmosphere'],
#   'polarity': ['positive', 'positive']},
#  10: {'id': '3195',
#   'text': 'visited thailand quite expert cuisine .',
#   'term': ['cuisine'],
#   'polarity': ['positive']},
#  11: {'id': '3359',
#   'text': 'pizza best like thincrustedpizza .',
#   'term': ['pizza', 'thincrustedpizza'],
#   'polarity': ['positive', 'neutral']},
#  12: {'id': '3534',
#   'text': 'money went interiordecoration , none went chefs .',
#   'term': ['interiordecoration', 'chefs'],
#   'polarity': ['positive', 'negative']},
#  13: {'id': '1407',
#   'text': 'seats uncomfortable sitting wall wooden benches .',
#   'term': ['seats'],
#   'polarity': ['negative']},
#  14: {'id': '565',
#   'text': 'asked seltzerwithlime , no ice .',
#   'term': ['seltzerwithlime'],
#   'polarity': ['neutral']},
#  15: {'id': '675',
#   'text': "n't go alone -- -even two people n't enough whole experience , pickles selectionofmeatsandseafoods .",
#   'term': ['pickles', 'selectionofmeatsandseafoods'],
#   'polarity': ['positive', 'positive']},
#  16: {'id': '2227',
#   'text': "suggestion eatfamilystyle 'll want try dishes .",
#   'term': ['dishes', 'eatfamilystyle'],
#   'polarity': ['neutral', 'positive']},
#  17: {'id': '3367',
#   'text': 'best warm vibe , owner super friendly service fast .',
#   'term': ['vibe', 'owner', 'service'],
#   'polarity': ['positive', 'positive', 'positive']},
#  18: {'id': '2191',
#   'text': "faan 's got great concept little rough delivery .",
#   'term': ['delivery'],
#   'polarity': ['negative']},
#  19: {'id': '270',
#   'text': "incredible food , warm atmosphere , friendly service , downtown neighborhood spot n't miss beat .",
#   'term': ['food', 'atmosphere', 'service'],
#   'polarity': ['positive', 'positive', 'positive']},
#  20: {'id': '638',
#   'text': "great food reasonable prices , makes evening ca n't beat !",
#   'term': ['food', 'prices'],
#   'polarity': ['positive', 'positive']},
#  21: {'id': '388',
#   'text': 'little place cute interiordecor affordable city prices .',
#   'term': ['interiordecor', 'prices'],
#   'polarity': ['positive', 'positive']},
#  22: {'id': '3373',
#   'text': 'two words : free wine .',
#   'term': ['wine'],
#   'polarity': ['positive']},
#  23: {'id': '425',
#   'text': 'price reasonable although service poor .',
#   'term': ['price', 'service'],
#   'polarity': ['positive', 'negative']},
#  24: {'id': '3192',
#   'text': 'quantity also good , come satisfied .',
#   'term': ['quantity'],
#   'polarity': ['positive']},
#  25: {'id': '391',
#   'text': 'stumbled upon second floor walk-up two fridays ago two friends town l.a. serious sushi lovers , sat sushibar closer action .',
#   'term': ['sushi', 'sushibar'],
#   'polarity': ['neutral', 'neutral']},
#  26: {'id': '2384',
#   'text': 'friedrice amazing .',
#   'term': ['friedrice'],
#   'polarity': ['positive']},
#  27: {'id': '2962',
#   'text': 'three courses - choices include excellent mussels , puffpastrygoatcheese saladwithadeliciousdressing , hangersteakaupoivre world .',
#   'term': ['mussels',
#    'puffpastrygoatcheese',
#    'saladwithadeliciousdressing',
#    'hangersteakaupoivre',
#    'courses'],
#   'polarity': ['positive', 'positive', 'positive', 'positive', 'neutral']},
#  28: {'id': '3404',
#   'text': "'s perfect place amanzing indianfood .",
#   'term': ['indianfood'],
#   'polarity': ['positive']},
#  29: {'id': '2599',
#   'text': 'place cool service prompt curtious .',
#   'term': ['service', 'place'],
#   'polarity': ['positive', 'positive']},
#  30: {'id': '673',
#   'text': "end 're left mild brothwithnoodles slurp cup .",
#   'term': ['brothwithnoodles'],
#   'polarity': ['positive']},
#  31: {'id': '648',
#   'text': 'wonder delicious meal little money .',
#   'term': ['meal', 'money'],
#   'polarity': ['positive', 'positive']},
#  32: {'id': '863',
#   'text': 'food delicious not come empty stomach .',
#   'term': ['food'],
#   'polarity': ['conflict']},
#  33: {'id': '1623',
#   'text': 'winelist excellent .',
#   'term': ['winelist'],
#   'polarity': ['positive']},
#  34: {'id': '430',
#   'text': "ive many thai restaurants manhattan , toons far best thaifood ive ( except mom 's course ) .",
#   'term': ['thaifood'],
#   'polarity': ['positive']},
#  35: {'id': '1101',
#   'text': 'wouldnt even let finish glassofwine offering another .',
#   'term': ['glassofwine'],
#   'polarity': ['neutral']},
#  36: {'id': '324',
#   'text': 'whem asked , ask detailed questions knew specials .',
#   'term': ['specials'],
#   'polarity': ['neutral']},
#  37: {'id': '2783',
#   'text': 'consistently great place dine lunch dinner .',
#   'term': ['lunch', 'dinner', 'dine'],
#   'polarity': ['neutral', 'neutral', 'positive']},
#  38: {'id': '2983',
#   'text': 'nice atmosphere , service pleasant desert good .',
#   'term': ['atmosphere', 'service', 'desert'],
#   'polarity': ['positive', 'positive', 'positive']},
#  39: {'id': '627',
#   'text': 'really enjoying bar sat table dinner .',
#   'term': ['bar', 'table', 'dinner'],
#   'polarity': ['positive', 'neutral', 'neutral']},
#  40: {'id': '3219',
#   'text': 'fabulous service , fantastic food , chilled atmosphere environment .',
#   'term': ['service', 'food', 'atmosphere', 'environment'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  41: {'id': '2787',
#   'text': 'try lasagnetteappetizer .',
#   'term': ['lasagnetteappetizer'],
#   'polarity': ['positive']},
#  42: {'id': '604',
#   'text': 'liked beerselection !',
#   'term': ['beerselection'],
#   'polarity': ['positive']},
#  43: {'id': '2911',
#   'text': 'great food , good size menu , great service unpretensious setting .',
#   'term': ['food', 'menu', 'service', 'setting'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  44: {'id': '3074',
#   'text': 'go romantic dinner not wow dining experience .',
#   'term': ['dinner', 'dining'],
#   'polarity': ['positive', 'positive']},
#  45: {'id': '1074',
#   'text': 'grew eating dosa yet find place ny satisfy taste buds .',
#   'term': ['dosa'],
#   'polarity': ['neutral']},
#  46: {'id': '912',
#   'text': 'winelistselection good wine-by-the-glass generously filled top .',
#   'term': ['winelistselection', 'wine-by-the-glass'],
#   'polarity': ['positive', 'positive']},
#  47: {'id': '728',
#   'text': 'great variety menu , eat often never get bored .',
#   'term': ['menu'],
#   'polarity': ['positive']},
#  48: {'id': '2925',
#   'text': 'menu limited - think counted 4 5 entrees .',
#   'term': ['menu', 'entrees'],
#   'polarity': ['negative', 'negative']},
#  49: {'id': '3436',
#   'text': 'menu limited almost dishes excellent .',
#   'term': ['menu', 'dishes'],
#   'polarity': ['negative', 'positive']},
#  50: {'id': '3273',
#   'text': 'not crazy sakemartini .',
#   'term': ['sakemartini'],
#   'polarity': ['negative']},
#  51: {'id': '1215',
#   'text': 'great bagels , spreads good place hang .',
#   'term': ['bagels', 'spreads'],
#   'polarity': ['positive', 'positive']},
#  52: {'id': '183',
#   'text': "service varys day day- sometimes 're nice , sometimes not .",
#   'term': ['service'],
#   'polarity': ['conflict']},
#  53: {'id': '282',
#   'text': 'one thing liked place never felt rushed pressured give table ot incoming guests .',
#   'term': ['table'],
#   'polarity': ['neutral']},
#  54: {'id': '3249',
#   'text': 'unfortunately , food outstanding , everything else restaurant pits .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  55: {'id': '3207',
#   'text': 'always delicious meal always leave feeling satisfied .',
#   'term': ['meal'],
#   'polarity': ['positive']},
#  56: {'id': '672',
#   'text': 'dip ingredients chopsticks , swirl around , eat .',
#   'term': ['ingredients', 'chopsticks'],
#   'polarity': ['neutral', 'neutral']},
#  57: {'id': '2972',
#   'text': 'first went enjoy gardenterrace .',
#   'term': ['gardenterrace'],
#   'polarity': ['positive']},
#  58: {'id': '1755',
#   'text': 'pizza pretty good huge .',
#   'term': ['pizza'],
#   'polarity': ['positive']},
#  59: {'id': '2277',
#   'text': "cuisine 've gathered authentic taiwanese , though different 've accustomed taipei .",
#   'term': ['cuisine'],
#   'polarity': ['neutral']},
#  60: {'id': '3680',
#   'text': 'almost hesititate write review atmosphere great would hate become crowded .',
#   'term': ['atmosphere'],
#   'polarity': ['positive']},
#  61: {'id': '3155',
#   'text': 'often crowded weekends efficient accurate service .',
#   'term': ['service', 'crowded'],
#   'polarity': ['positive', 'negative']},
#  62: {'id': '1688',
#   'text': 'co-workers amazed small dish .',
#   'term': ['dish'],
#   'polarity': ['negative']},
#  63: {'id': '598',
#   'text': 'atmosphere unheralded , service impecible , food magnificant .',
#   'term': ['atmosphere', 'service', 'food'],
#   'polarity': ['positive', 'positive', 'positive']},
#  64: {'id': '2926',
#   'text': 'ordered special , grilledbranzino , infused bone , difficult eat .',
#   'term': ['grilledbranzino'],
#   'polarity': ['negative']},
#  65: {'id': '3083',
#   'text': 'waitstaff friendly , food gotten better better !',
#   'term': ['waitstaff', 'food'],
#   'polarity': ['positive', 'positive']},
#  66: {'id': '2977',
#   'text': 'may bit packed weekends , vibe good best frenchfood find area .',
#   'term': ['vibe', 'frenchfood', 'packed'],
#   'polarity': ['positive', 'positive', 'negative']},
#  67: {'id': '2604',
#   'text': 'right l brooklyn nice cozy place good pizza .',
#   'term': ['pizza', 'place'],
#   'polarity': ['positive', 'positive']},
#  68: {'id': '2960',
#   'text': 'le pere pinard $ 15 pre-theatermenu outstanding .',
#   'term': ['pre-theatermenu'],
#   'polarity': ['positive']},
#  69: {'id': '1383',
#   'text': 'also ordered delivery restaurant forgot half order .',
#   'term': ['delivery', 'order'],
#   'polarity': ['negative', 'negative']},
#  70: {'id': '892',
#   'text': 'server checked us maybe twice entire meal .',
#   'term': ['server', 'meal'],
#   'polarity': ['negative', 'neutral']},
#  71: {'id': '2936',
#   'text': 'strong scents coming left right negatively affected taste buds .',
#   'term': ['scents'],
#   'polarity': ['negative']},
#  72: {'id': '3423',
#   'text': 'lobstersandwich fantastic .',
#   'term': ['lobstersandwich'],
#   'polarity': ['positive']},
#  73: {'id': '1197',
#   'text': "stalling could understand coming , less hour n't even brought us check yet !",
#   'term': ['check'],
#   'polarity': ['negative']},
#  74: {'id': '2274',
#   'text': 'though spiderroll may look like challenge eat , soft shellcrab hanging roll , well worth price pay .',
#   'term': ['spiderroll', 'price', 'shellcrab'],
#   'polarity': ['conflict', 'positive', 'positive']},
#  75: {'id': '2804',
#   'text': 'deepfriedskewers good still rare find nyc .',
#   'term': ['deepfriedskewers'],
#   'polarity': ['positive']},
#  76: {'id': '194',
#   'text': "tried make reservations , times , hostess n't name .",
#   'term': ['reservations', 'hostess'],
#   'polarity': ['neutral', 'negative']},
#  77: {'id': '148',
#   'text': 'also recommend ricedishes different varieties congee ( riceporridge ) .',
#   'term': ['ricedishes', 'congee(riceporridge)'],
#   'polarity': ['positive', 'positive']},
#  78: {'id': '2747',
#   'text': 'tunatartarappetizer die .',
#   'term': ['tunatartarappetizer'],
#   'polarity': ['positive']},
#  79: {'id': '856',
#   'text': "oasis refinement : food , though somewhat uneven , often reaches pinnacles new american fine cuisine - chef 's passion ( kitchen 's precise execution ) evident fishdishes soups .",
#   'term': ['food', 'chef', 'fishdishes', 'soups', 'kitchen', 'cuisine'],
#   'polarity': ['conflict',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive']},
#  80: {'id': '2033',
#   'text': "love wine cheese delicious frenchfare , 'll love artisanal !",
#   'term': ['wine', 'frenchfare', 'cheese'],
#   'polarity': ['positive', 'positive', 'positive']},
#  81: {'id': '1402',
#   'text': 'love indianfood consider quite expert .',
#   'term': ['indianfood'],
#   'polarity': ['positive']},
#  82: {'id': '439',
#   'text': 'babypizzas get wish .',
#   'term': ['babypizzas'],
#   'polarity': ['neutral']},
#  83: {'id': '2053',
#   'text': 'overall oh ya even though waiting deff worth',
#   'term': ['waiting'],
#   'polarity': ['negative']},
#  84: {'id': '3316',
#   'text': 'lavacakedessert incredible recommend .',
#   'term': ['lavacakedessert'],
#   'polarity': ['positive']},
#  85: {'id': '433',
#   'text': 'vt babypizzas hope grow .',
#   'term': ['babypizzas'],
#   'polarity': ['neutral']},
#  86: {'id': '738',
#   'text': 'terrible service , bland food , not mention unaccommodating managers , overall experience horrible .',
#   'term': ['service', 'food', 'managers'],
#   'polarity': ['negative', 'negative', 'negative']},
#  87: {'id': '1549',
#   'text': "lahore great place duck late-night need really tasty food cheap -- 'll likely trouble finishing amount food get four dollars .",
#   'term': ['food', 'food'],
#   'polarity': ['positive', 'positive']},
#  88: {'id': '1798',
#   'text': 'last time went seated table corridor next kitchen .',
#   'term': ['table'],
#   'polarity': ['negative']},
#  89: {'id': '2941',
#   'text': 'good selectionofwines ranging affordable high end .',
#   'term': ['selectionofwines'],
#   'polarity': ['positive']},
#  90: {'id': '362',
#   'text': 'nice restaurant overall , classic upscale italiandecor .',
#   'term': ['italiandecor'],
#   'polarity': ['positive']},
#  91: {'id': '2921',
#   'text': 'not impressed food .',
#   'term': ['food'],
#   'polarity': ['negative']},
#  92: {'id': '1909',
#   'text': 'entire diningexperience wonderful !',
#   'term': ['diningexperience'],
#   'polarity': ['positive']},
#  93: {'id': '1878',
#   'text': "wineselection ( glass bottle ) wonderful always recommend friends make reservation 're going town .",
#   'term': ['wineselection', 'reservation'],
#   'polarity': ['positive', 'neutral']},
#  94: {'id': '858',
#   'text': "service highly refined : seating delayed 35 minutes past reservation maitre ' apologized regularly kept us apprised progress .",
#   'term': ['service', 'maitre', 'reservation'],
#   'polarity': ['positive', 'positive', 'negative']},
#  95: {'id': '3376',
#   'text': "order panangduck , 's fantastic .",
#   'term': ['panangduck'],
#   'polarity': ['positive']},
#  96: {'id': '173',
#   'text': 'food usually good , though ocasionally wondered freshmess rawvegatables side orders .',
#   'term': ['food', 'rawvegatables'],
#   'polarity': ['conflict', 'negative']},
#  97: {'id': '1836',
#   'text': "crappy service two individuals , 's great .",
#   'term': ['service'],
#   'polarity': ['negative']},
#  98: {'id': '1404',
#   'text': 'authentic indian amazin prices .',
#   'term': ['indian', 'prices'],
#   'polarity': ['positive', 'positive']},
#  99: {'id': '1819',
#   'text': 'ambiance- relaxed stylish .',
#   'term': ['ambiance'],
#   'polarity': ['positive']},
#  100: {'id': '2639',
#   'text': 'luckily saved room bbqsalmon , seabass crispyduck .',
#   'term': ['bbqsalmon', 'seabass', 'crispyduck'],
#   'polarity': ['positive', 'positive', 'positive']},
#  101: {'id': '1474',
#   'text': "yes , use fancy ingredients , even fancy ingredients n't make good pizza unless someone knows get crust right .",
#   'term': ['ingredients', 'ingredients', 'pizza', 'crust'],
#   'polarity': ['positive', 'positive', 'negative', 'neutral']},
#  102: {'id': '2059',
#   'text': 'yes dalbukhara dam good kababs .',
#   'term': ['kababs', 'dalbukhara'],
#   'polarity': ['positive', 'positive']},
#  103: {'id': '926',
#   'text': 'look forward eating',
#   'term': ['eating'],
#   'polarity': ['positive']},
#  104: {'id': '2385',
#   'text': "'ve coming child always come back taste .",
#   'term': ['taste'],
#   'polarity': ['positive']},
#  105: {'id': '2498',
#   'text': 'tuk tuk one comfortable neighborhood joints know always good meal fair price .',
#   'term': ['meal', 'price'],
#   'polarity': ['positive', 'positive']},
#  106: {'id': '2469',
#   'text': 'glassofleapinglizard , glassofprosecco , mussels everything happy .',
#   'term': ['glassofprosecco', 'mussels', 'glassofleapinglizard'],
#   'polarity': ['positive', 'positive', 'positive']},
#  107: {'id': '567',
#   'text': 'food average cremebrulee awful - sugar charred , not caramelized smelled kerosene .',
#   'term': ['food', 'cremebrulee', 'sugar'],
#   'polarity': ['neutral', 'negative', 'negative']},
#  108: {'id': '3517',
#   'text': 'food always tastes fresh served promptly .',
#   'term': ['food', 'served'],
#   'polarity': ['positive', 'positive']},
#  109: {'id': '1599',
#   'text': 'pizza delicious .',
#   'term': ['pizza'],
#   'polarity': ['positive']},
#  110: {'id': '2548',
#   'text': 'pizza garlicknots great well , order quite often delivery always super quick !',
#   'term': ['pizza', 'delivery', 'garlicknots'],
#   'polarity': ['positive', 'positive', 'positive']},
#  111: {'id': '759',
#   'text': 'great chinesefood nearby , wu liang ye grand sichuan block away .',
#   'term': ['chinesefood'],
#   'polarity': ['positive']},
#  112: {'id': '3175',
#   'text': "says murray 's anything service .",
#   'term': ['service'],
#   'polarity': ['neutral']},
#  113: {'id': '2209',
#   'text': 'place really trendi forgotten important part restaurant , food .',
#   'term': ['food'],
#   'polarity': ['negative']},
#  114: {'id': '1352',
#   'text': 'hats chef .',
#   'term': ['chef'],
#   'polarity': ['positive']},
#  115: {'id': '3537',
#   'text': 'service could improved overall place understands importance little things ( heavy , black , antique-seeming teapot , one ) restaurant experience .',
#   'term': ['service', 'teapot'],
#   'polarity': ['negative', 'positive']},
#  116: {'id': '1743',
#   'text': "pizza delicious - use freshmozzarella instead cheap , frozen , shredded cheese common pizzaria 's .",
#   'term': ['pizza', 'freshmozzarella', 'cheese'],
#   'polarity': ['positive', 'positive', 'negative']},
#  117: {'id': '1321',
#   'text': 'excellent place relax food one best city new york .',
#   'term': ['place', 'food'],
#   'polarity': ['positive', 'positive']},
#  118: {'id': '2907',
#   'text': 'service friendly , never problem walking gettingatable .',
#   'term': ['service', 'gettingatable'],
#   'polarity': ['positive', 'positive']},
#  119: {'id': '1890',
#   'text': 'atmosphere crowded great bistro-typevibe .',
#   'term': ['atmosphere', 'bistro-typevibe'],
#   'polarity': ['conflict', 'positive']},
#  120: {'id': '2588',
#   'text': 'first , waitress completely unattentive 2 times saw ( odd restaurant 6 tables ) got order wrong .',
#   'term': ['waitress', 'tables'],
#   'polarity': ['negative', 'neutral']},
#  121: {'id': '3130',
#   'text': 'food bland oily .',
#   'term': ['food'],
#   'polarity': ['negative']},
#  122: {'id': '709',
#   'text': 'even better , prices affordable well , food really good .',
#   'term': ['prices', 'food'],
#   'polarity': ['positive', 'positive']},
#  123: {'id': '1198',
#   'text': 'fish fresh varietyoffish nothing ordinary .',
#   'term': ['fish', 'varietyoffish'],
#   'polarity': ['positive', 'negative']},
#  124: {'id': '2302',
#   'text': 'favorite meal pestopizza , housesalad , good bottleofwine .',
#   'term': ['pestopizza', 'housesalad', 'bottleofwine', 'meal'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  125: {'id': '1110',
#   'text': 'kruno , beveragemanager best bartender yet come across .',
#   'term': ['bartender', 'beveragemanager'],
#   'polarity': ['positive', 'positive']},
#  126: {'id': '973',
#   'text': 'ambiance music funky , enjoy .',
#   'term': ['ambiance', 'music'],
#   'polarity': ['positive', 'positive']},
#  127: {'id': '2132',
#   'text': 'food , drinks service clearly among best city .',
#   'term': ['food', 'drinks', 'service'],
#   'polarity': ['positive', 'positive', 'positive']},
#  128: {'id': '231',
#   'text': 'went late afternoon bite size food refleshment date .',
#   'term': ['food', 'refleshment'],
#   'polarity': ['neutral', 'neutral']},
#  129: {'id': '250',
#   'text': 'understand area folks need not come romantic , alluring ambiance five star service featuring sommlier complicated maze captain backwaiters - come authentic foods , tastes , experiance .',
#   'term': ['ambiance',
#    'service',
#    'foods',
#    'tastes',
#    'sommlier',
#    'captain',
#    'backwaiters'],
#   'polarity': ['positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive']},
#  130: {'id': '2988',
#   'text': "last time went , waitress n't come back taking order .",
#   'term': ['waitress'],
#   'polarity': ['negative']},
#  131: {'id': '3092',
#   'text': 'try tandoorisalmon !',
#   'term': ['tandoorisalmon'],
#   'polarity': ['positive']},
#  132: {'id': '3686',
#   'text': "eating , atmosphere saves , desk , 's disappointing experience .",
#   'term': ['atmosphere'],
#   'polarity': ['positive']},
#  133: {'id': '1922',
#   'text': 'granted space smaller , best service find even largest restaurants .',
#   'term': ['space', 'service'],
#   'polarity': ['negative', 'positive']},
#  134: {'id': '2454',
#   'text': 'love atmorphere @ peep !',
#   'term': ['atmorphere'],
#   'polarity': ['positive']},
#  135: {'id': '603',
#   'text': 'service attentive suggestions menuitems right mark .',
#   'term': ['service', 'menuitems'],
#   'polarity': ['positive', 'positive']},
#  136: {'id': '678',
#   'text': 'night $ 30 threecoursemeal everything delicious - could licked plate clean would .',
#   'term': ['threecoursemeal'],
#   'polarity': ['positive']},
#  137: {'id': '1830',
#   'text': "even getting pushed no-class famous ray 's , sal risen carry father 's uncle 's legacies smile , true love community , let 's not forget outstanding pizza !",
#   'term': ['pizza'],
#   'polarity': ['positive']},
#  138: {'id': '2521',
#   'text': 'environment romantic , food horrible , service pathetic , gabriella lies everything could .',
#   'term': ['environment', 'food', 'service'],
#   'polarity': ['positive', 'negative', 'negative']},
#  139: {'id': '1918',
#   'text': 'crawfishboiled despite making mess , ton fun quite tasty well .',
#   'term': ['crawfishboiled'],
#   'polarity': ['positive']},
#  140: {'id': '2930',
#   'text': 'high expectations place made reservation couple months advance special occasion .',
#   'term': ['reservation'],
#   'polarity': ['neutral']},
#  141: {'id': '887',
#   'text': 'came table burned beyond recognition stringy .',
#   'term': ['table'],
#   'polarity': ['neutral']},
#  142: {'id': '2448',
#   'text': 'padthai noodles sticky .',
#   'term': ['padthai', 'noodles'],
#   'polarity': ['negative', 'negative']},
#  143: {'id': '3244',
#   'text': "'ve never actually proper , 've delivered times .",
#   'term': ['delivered'],
#   'polarity': ['neutral']},
#  144: {'id': '1478',
#   'text': 'among new 5th avenue restaurants , offers far one best valuesforyourmoney .',
#   'term': ['valuesforyourmoney'],
#   'polarity': ['positive']},
#  145: {'id': '1413',
#   'text': 'frankly , compare lunch , versus mcds many sandwich shops city , no comparison .',
#   'term': ['lunch'],
#   'polarity': ['positive']},
#  146: {'id': '3129',
#   'text': 'hostess rude point offensive .',
#   'term': ['hostess'],
#   'polarity': ['negative']},
#  147: {'id': '2271',
#   'text': "'re craving haru 's great food , especially house roll , ca n't stand waitbuilding outisde , head across street sake bar !",
#   'term': ['food', 'waitbuilding'],
#   'polarity': ['positive', 'negative']},
#  148: {'id': '1554',
#   'text': 'narrow corridor leads tiny space three tiny white tiled counters , great deal mess ( stacks bottles , cans ) small counter holding 12-14 entrees .',
#   'term': ['corridor', 'space', 'counters', 'counter', 'entrees'],
#   'polarity': ['negative', 'negative', 'negative', 'negative', 'neutral']},
#  149: {'id': '2306',
#   'text': 'food great .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  150: {'id': '1975',
#   'text': "succulent steaks cooked precisely desired 'doneness ' accompanied salads sides n't look like leafy road kill .",
#   'term': ['steaks', 'salads', 'sides'],
#   'polarity': ['positive', 'positive', 'positive']},
#  151: {'id': '3699',
#   'text': 'lunch came pickelsandslaw , no extra charge .',
#   'term': ['lunch', 'pickelsandslaw'],
#   'polarity': ['positive', 'neutral']},
#  152: {'id': '2875',
#   'text': 'decent wine reasonable prices .',
#   'term': ['wine', 'prices'],
#   'polarity': ['positive', 'positive']},
#  153: {'id': '2303',
#   'text': 'conveniently delivered right door .',
#   'term': ['delivered'],
#   'polarity': ['positive']},
#  154: {'id': '2513',
#   'text': 'even winebytheglass good .',
#   'term': ['winebytheglass'],
#   'polarity': ['positive']},
#  155: {'id': '809',
#   'text': 'would rather tried terrace sky water club price',
#   'term': ['price'],
#   'polarity': ['negative']},
#  156: {'id': '141',
#   'text': 'dish favorite always get go never get tired .',
#   'term': ['dish'],
#   'polarity': ['positive']},
#  157: {'id': '3655',
#   'text': 'also ordered changemojito , world .',
#   'term': ['changemojito'],
#   'polarity': ['positive']},
#  158: {'id': '2098',
#   'text': 'okay service .',
#   'term': ['service'],
#   'polarity': ['neutral']},
#  159: {'id': '1624',
#   'text': 'thing wonderful food ( exceptional ) service .',
#   'term': ['food', 'service'],
#   'polarity': ['positive', 'positive']},
#  160: {'id': '2377',
#   'text': 'food awful , atrocious actually .',
#   'term': ['food'],
#   'polarity': ['negative']},
#  161: {'id': '338',
#   'text': 'soupfortheudon soysauce water .',
#   'term': ['soupfortheudon', 'soysauce', 'water'],
#   'polarity': ['negative', 'neutral', 'neutral']},
#  162: {'id': '1630',
#   'text': 'anti-pasta excellent , especially calamari , fillingpastamains .',
#   'term': ['anti-pasta', 'calamari', 'fillingpastamains'],
#   'polarity': ['positive', 'positive', 'positive']},
#  163: {'id': '1907',
#   'text': 'waitress suggested glassesofwine went well food .',
#   'term': ['waitress', 'food', 'glassesofwine'],
#   'polarity': ['positive', 'neutral', 'positive']},
#  164: {'id': '1535',
#   'text': 'might business counter give order , food says love .',
#   'term': ['food', 'counter'],
#   'polarity': ['positive', 'negative']},
#  165: {'id': '3202',
#   'text': 'particular sushi please every choice included : cevichemix ( special ) , crabdumplings , assortedsashimi , sushi rolls , two types sake , bananatempura .',
#   'term': ['sushi',
#    'cevichemix(special)',
#    'crabdumplings',
#    'assortedsashimi',
#    'sushi',
#    'rolls',
#    'sake',
#    'bananatempura'],
#   'polarity': ['positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive']},
#  166: {'id': '449',
#   'text': 'try plainpizza fresh garlic eggplant .',
#   'term': ['plainpizza', 'garlic', 'eggplant'],
#   'polarity': ['positive', 'positive', 'positive']},
#  167: {'id': '927',
#   'text': "ok , servers wander around little clueless , 's enough servers crowd get -- 's fine , make small effort get attention .",
#   'term': ['servers', 'servers'],
#   'polarity': ['negative', 'conflict']},
#  168: {'id': '585',
#   'text': 'good luck gettingatable .',
#   'term': ['gettingatable'],
#   'polarity': ['negative']},
#  169: {'id': '345',
#   'text': 'service awful .',
#   'term': ['service'],
#   'polarity': ['negative']},
#  170: {'id': '1494',
#   'text': "takeoutmenu says keep eye expanded menu offering italiandishes , ca n't wait !",
#   'term': ['takeoutmenu', 'menu', 'italiandishes'],
#   'polarity': ['positive', 'positive', 'positive']},
#  171: {'id': '3194',
#   'text': 'not experienced person comes thaifood , friend took .',
#   'term': ['thaifood'],
#   'polarity': ['neutral']},
#  172: {'id': '2393',
#   'text': 'regardless whether two people two hundred people ahead hostess take name tell five minutes .',
#   'term': ['hostess'],
#   'polarity': ['positive']},
#  173: {'id': '1278',
#   'text': 'pizza good though .',
#   'term': ['pizza'],
#   'polarity': ['positive']},
#  174: {'id': '2201',
#   'text': 'bottlesofwine cheap good .',
#   'term': ['bottlesofwine'],
#   'polarity': ['positive']},
#  175: {'id': '620',
#   'text': '100 different beers offer thier guest made husband happy food delicious , must recommend dish must pumkintortelini .',
#   'term': ['beers', 'food', 'pumkintortelini', 'dish'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  176: {'id': '3541',
#   'text': "n't give us dinnerspecial asked .",
#   'term': ['dinnerspecial'],
#   'polarity': ['negative']},
#  177: {'id': '865',
#   'text': 'must crabmeatlasagna world chocolatebreadpudding dessert .',
#   'term': ['crabmeatlasagna', 'chocolatebreadpudding', 'dessert'],
#   'polarity': ['positive', 'positive', 'positive']},
#  178: {'id': '375',
#   'text': "word advice , save room pastadishes never leave 've tiramisu .",
#   'term': ['pastadishes', 'tiramisu'],
#   'polarity': ['positive', 'positive']},
#  179: {'id': '2126',
#   'text': 'good service good prices .',
#   'term': ['service', 'prices'],
#   'polarity': ['positive', 'positive']},
#  180: {'id': '2078',
#   'text': 'recently went restaurant co-workers lunch amazing time .',
#   'term': ['lunch'],
#   'polarity': ['neutral']},
#  181: {'id': '846',
#   'text': 'service impeccable unobtrusive -- staff knows -- know menu , present meal , attend needs .',
#   'term': ['service', 'staff', 'menu', 'meal'],
#   'polarity': ['positive', 'positive', 'neutral', 'neutral']},
#  182: {'id': '2158',
#   'text': 'ess-a-bagel ( either sty-town midtown ) far best bagel ny .',
#   'term': ['bagel'],
#   'polarity': ['positive']},
#  183: {'id': '1578',
#   'text': 'food great !',
#   'term': ['food'],
#   'polarity': ['positive']},
#  184: {'id': '1319',
#   'text': 'annoying thing , though , fact servers seem trained drive revenue .',
#   'term': ['servers'],
#   'polarity': ['negative']},
#  185: {'id': '1175',
#   'text': 'get food go , find bench , kick back plateofdumplings .',
#   'term': ['food', 'plateofdumplings'],
#   'polarity': ['neutral', 'positive']},
#  186: {'id': '1115',
#   'text': 'please try filetmignon , tender piece ever .',
#   'term': ['filetmignon'],
#   'polarity': ['positive']},
#  187: {'id': '34',
#   'text': 'still sitting bar drank sangria , facing away bar turned back around , $ 2 gone people next us said bartender took .',
#   'term': ['sangria', 'bar', 'bar', 'bartender'],
#   'polarity': ['neutral', 'neutral', 'neutral', 'negative']},
#  188: {'id': '395',
#   'text': 'sakemenu not overlooked !',
#   'term': ['sakemenu'],
#   'polarity': ['positive']},
#  189: {'id': '3102',
#   'text': 'drinks amazing half till 8pm .',
#   'term': ['drinks'],
#   'polarity': ['positive']},
#  190: {'id': '984',
#   'text': "'ve back nha trang literally hundred times beefcubes - 're good .",
#   'term': ['beefcubes'],
#   'polarity': ['positive']},
#  191: {'id': '1969',
#   'text': 'service , wineselection , ambiance outstanding deserve recognition .',
#   'term': ['service', 'wineselection', 'ambiance'],
#   'polarity': ['positive', 'positive', 'positive']},
#  192: {'id': '763',
#   'text': 'seated promptly reservations , however service slow .',
#   'term': ['reservations', 'service'],
#   'polarity': ['positive', 'negative']},
#  193: {'id': '754',
#   'text': "'s really also service , good waiters friendly .",
#   'term': ['service', 'waiters'],
#   'polarity': ['positive', 'positive']},
#  194: {'id': '691',
#   'text': 'food pretty good , little flavorless portions small , including dessert .',
#   'term': ['food', 'dessert', 'portions'],
#   'polarity': ['conflict', 'negative', 'negative']},
#  195: {'id': '999',
#   'text': "set far small street 's , no trafficnoise .",
#   'term': ['trafficnoise'],
#   'polarity': ['positive']},
#  196: {'id': '247',
#   'text': 'lived shanghai life thought food comparable flagship green bo restaurant .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  197: {'id': '2823',
#   'text': "highly recommend cafe st. bart 's food , ambience wonderful service .",
#   'term': ['food', 'ambience', 'service'],
#   'polarity': ['positive', 'positive', 'positive']},
#  198: {'id': '2649',
#   'text': 'nice restaurant looking good place host intimate dinnermeeting business associates .',
#   'term': ['dinnermeeting'],
#   'polarity': ['neutral']},
#  199: {'id': '2396',
#   'text': 'nyu students love place makes fun young atmosphere .',
#   'term': ['atmosphere'],
#   'polarity': ['positive']},
#  200: {'id': '139',
#   'text': 'food great service name ( cantonese ... ) .',
#   'term': ['food', 'cantonese'],
#   'polarity': ['positive', 'positive']},
#  201: {'id': '841',
#   'text': ', nothing stands cooking .',
#   'term': ['cooking'],
#   'polarity': ['neutral']},
#  202: {'id': '3477',
#   'text': 'joya used cool spot decent food colorful - not relaxed - atmosphere .',
#   'term': ['food', 'atmosphere'],
#   'polarity': ['positive', 'positive']},
#  203: {'id': '90',
#   'text': 'prixfixemenu worth every penny get enough ( quantity quality ) .',
#   'term': ['prixfixemenu', 'quantity', 'quality'],
#   'polarity': ['positive', 'positive', 'positive']},
#  204: {'id': '298',
#   'text': "'ve 3 times lunch one favorites city .",
#   'term': ['lunch'],
#   'polarity': ['neutral']},
#  205: {'id': '1104',
#   'text': 'eggsbenedict brunch , worst entire life , tried removing hollondaisesauce completely failed .',
#   'term': ['eggsbenedict', 'hollondaisesauce', 'brunch'],
#   'polarity': ['negative', 'negative', 'neutral']},
#  206: {'id': '2563',
#   'text': 'work near-by , best oatmeal neighborhood- not packaged quick-cooked item .',
#   'term': ['oatmeal'],
#   'polarity': ['positive']},
#  207: {'id': '2790',
#   'text': "bad food n't heritage .",
#   'term': ['food'],
#   'polarity': ['negative']},
#  208: {'id': '323',
#   'text': 'menu looked good , except offering chileanseabass , server not offer specials written board outside .',
#   'term': ['menu', 'chileanseabass', 'server', 'specials'],
#   'polarity': ['positive', 'negative', 'negative', 'neutral']},
#  209: {'id': '1891',
#   'text': 'food really good , onionsoup one best ever .',
#   'term': ['food', 'onionsoup'],
#   'polarity': ['positive', 'positive']},
#  210: {'id': '3451',
#   'text': 'overall , solid restaurant less $ 40pp ( including wine ) , solid deal well .',
#   'term': ['wine'],
#   'polarity': ['neutral']},
#  211: {'id': '1551',
#   'text': "since literally complete hole wall , 's bit intimidating first , get quickly soon friendly staff welcomes - n't hesitate ask help get .",
#   'term': ['staff'],
#   'polarity': ['positive']},
#  212: {'id': '3146',
#   'text': 'based reviews dinner , place would reconsider revisiting , definitely not dimsum .',
#   'term': ['dimsum', 'dinner'],
#   'polarity': ['negative', 'positive']},
#  213: {'id': '1785',
#   'text': "costs $ 2 extra turn regular roll inside-out roll , roll triples size , 's not rice .",
#   'term': ['roll', 'roll', 'roll', 'rice'],
#   'polarity': ['negative', 'negative', 'negative', 'neutral']},
#  214: {'id': '3650',
#   'text': "finally , unable make ginandtonic -- could n't find tonic .",
#   'term': ['ginandtonic', 'tonic'],
#   'polarity': ['neutral', 'neutral']},
#  215: {'id': '2084',
#   'text': "dimsum ok n't taste fresh , littledishes n't look steamy hot ( also note lack chinese ) .",
#   'term': ['dimsum', 'littledishes'],
#   'polarity': ['negative', 'negative']},
#  216: {'id': '3193',
#   'text': "service ok , people n't get asked .",
#   'term': ['service'],
#   'polarity': ['neutral']},
#  217: {'id': '2212',
#   'text': 'want good authentic thai place not place go .',
#   'term': ['thai'],
#   'polarity': ['negative']},
#  218: {'id': '3426',
#   'text': 'recommend getting reservation even though saw people seated without one .',
#   'term': ['reservation'],
#   'polarity': ['neutral']},
#  219: {'id': '1138',
#   'text': 'thing moderately enjoyed grilledchickenspecialwithedamamepuree .',
#   'term': ['grilledchickenspecialwithedamamepuree'],
#   'polarity': ['neutral']},
#  220: {'id': '128',
#   'text': 'want roastduck , pork chickenonricewithginger , try !',
#   'term': ['roastduck', 'pork', 'chickenonricewithginger'],
#   'polarity': ['positive', 'positive', 'positive']},
#  221: {'id': '1008',
#   'text': 'order menu , leave feeling like missed full experience .',
#   'term': ['menu'],
#   'polarity': ['negative']},
#  222: {'id': '2124',
#   'text': 'staff accomodating .',
#   'term': ['staff'],
#   'polarity': ['positive']},
#  223: {'id': '1950',
#   'text': "went del frisco 's friday night boyfriend 8:00 reservation .",
#   'term': ['reservation'],
#   'polarity': ['neutral']},
#  224: {'id': '1133',
#   'text': 'favor dinner see dont agree .',
#   'term': ['dinner'],
#   'polarity': ['neutral']},
#  225: {'id': '2801',
#   'text': 'popular style izakaya ( sake small portion sake-friendly dishes ) .',
#   'term': ['sake', 'dishes', 'portion'],
#   'polarity': ['positive', 'positive', 'neutral']},
#  226: {'id': '224',
#   'text': 'food terrific service classy , attentive , without overbearing .',
#   'term': ['food', 'service'],
#   'polarity': ['positive', 'positive']},
#  227: {'id': '2434',
#   'text': 'amazing place try rotirolls .',
#   'term': ['rotirolls'],
#   'polarity': ['positive']},
#  228: {'id': '459',
#   'text': 'fresh ingredients everything made order .',
#   'term': ['ingredients'],
#   'polarity': ['positive']},
#  229: {'id': '3042',
#   'text': 'never problems charging meal tip , food delivered quickly , live minutes walk .',
#   'term': ['meal', 'food', 'tip'],
#   'polarity': ['positive', 'positive', 'positive']},
#  230: {'id': '152',
#   'text': 'quick friendly service .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  231: {'id': '2426',
#   'text': 'tasty , suggest eating one meat tend not mesh well average american digestive system .',
#   'term': ['meat'],
#   'polarity': ['neutral']},
#  232: {'id': '494',
#   'text': "try hotdogs , 're snappy delicious .",
#   'term': ['hotdogs'],
#   'polarity': ['positive']},
#  233: {'id': '1033',
#   'text': 'delivery fast .',
#   'term': ['delivery'],
#   'polarity': ['positive']},
#  234: {'id': '2486',
#   'text': 'noiselevel unbearable , conversation impossible .',
#   'term': ['noiselevel'],
#   'polarity': ['negative']},
#  235: {'id': '2307',
#   'text': 'personalpans perfect size hungry nights .',
#   'term': ['personalpans'],
#   'polarity': ['positive']},
#  236: {'id': '1646',
#   'text': 'highly recommended spicyfriedclamrolls spiderrolls .',
#   'term': ['spicyfriedclamrolls', 'spiderrolls'],
#   'polarity': ['positive', 'positive']},
#  237: {'id': '3255',
#   'text': 'one earlier people commenting restaurant not get experimenting going menu positive way .',
#   'term': ['menu'],
#   'polarity': ['positive']},
#  238: {'id': '318',
#   'text': 'atmosphere great looking laid back scene inexpensive way spend weekend afternoon .',
#   'term': ['atmosphere'],
#   'polarity': ['positive']},
#  239: {'id': '198',
#   'text': 'odd ave b , not odd , place attracts eclectic crowd say least .',
#   'term': ['place'],
#   'polarity': ['positive']},
#  240: {'id': '1269',
#   'text': 'instead wasting time : support restaurants care food .',
#   'term': ['food'],
#   'polarity': ['neutral']},
#  241: {'id': '2062',
#   'text': 'got back lunch tamarind excellent .',
#   'term': ['lunch'],
#   'polarity': ['positive']},
#  242: {'id': '3557',
#   'text': "head shoulders neighboors east 6 st , taj mahal also comparable , foodquality , much overpraised ( underdeserving ) baluchi 's .",
#   'term': ['foodquality'],
#   'polarity': ['positive']},
#  243: {'id': '38',
#   'text': 'man hosting promised save table party 7 , sat party 2 table saving ( mean boths open around ) .',
#   'term': ['man', 'table', 'table'],
#   'polarity': ['negative', 'neutral', 'negative']},
#  244: {'id': '1957',
#   'text': 'try cheesecake !',
#   'term': ['cheesecake'],
#   'polarity': ['positive']},
#  245: {'id': '1542',
#   'text': 'sitting eating subpar food manager proceeded berate couple employees putting wrong containersforcondiments explained expensive containers .',
#   'term': ['food',
#    'employees',
#    'containersforcondiments',
#    'containers',
#    'manager'],
#   'polarity': ['negative', 'negative', 'negative', 'neutral', 'negative']},
#  246: {'id': '2328',
#   'text': 'great indianfood service incredible .',
#   'term': ['indianfood', 'service'],
#   'polarity': ['positive', 'positive']},
#  247: {'id': '504',
#   'text': 'decor nice minimalist , food simple yet well presented cooked , winelist matches food well .',
#   'term': ['decor', 'food', 'winelist', 'food'],
#   'polarity': ['positive', 'positive', 'positive', 'neutral']},
#  248: {'id': '1853',
#   'text': 'salmondish fine , price paid , expected type flavor .',
#   'term': ['salmondish', 'flavor', 'price'],
#   'polarity': ['conflict', 'negative', 'neutral']},
#  249: {'id': '1538',
#   'text': 'ordered tunamelt - came cheese made tunasandwich .',
#   'term': ['tunamelt', 'cheese', 'tunasandwich'],
#   'polarity': ['negative', 'neutral', 'negative']},
#  250: {'id': '2482',
#   'text': 'especially liked chickentikka naan , dals .',
#   'term': ['chickentikka', 'naan', 'dals'],
#   'polarity': ['positive', 'positive', 'positive']},
#  251: {'id': '791',
#   'text': 'waiters not attentive except bill turned table finished .',
#   'term': ['waiters', 'bill'],
#   'polarity': ['negative', 'negative']},
#  252: {'id': '998',
#   'text': 'restaurant looks beautiful green lawns hudson river statue liberty .',
#   'term': ['lawns'],
#   'polarity': ['positive']},
#  253: {'id': '2872',
#   'text': 'wife always enjoy young , not always well trained nevertheless friendly , staff , story .',
#   'term': ['staff'],
#   'polarity': ['conflict']},
#  254: {'id': '2607',
#   'text': 'sangria pretty tasty good hot muggy day .',
#   'term': ['sangria'],
#   'polarity': ['positive']},
#  255: {'id': '1272',
#   'text': "n't eat unless 're starving thaifood work next door .",
#   'term': ['thaifood'],
#   'polarity': ['negative']},
#  256: {'id': '3578',
#   'text': 'people want great food plus great service , roxy place avoid !',
#   'term': ['food', 'service'],
#   'polarity': ['negative', 'negative']},
#  257: {'id': '572',
#   'text': 'best ravioli ever .',
#   'term': ['ravioli'],
#   'polarity': ['positive']},
#  258: {'id': '2500',
#   'text': "menu n't especially groundbreaking , everything 've tried far well-executed tasty .",
#   'term': ['menu'],
#   'polarity': ['conflict']},
#  259: {'id': '45',
#   'text': 'ive bunch times service always outstanding .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  260: {'id': '2445',
#   'text': 'bill approximately $ 25 2 lunch without drinks .',
#   'term': ['bill', 'lunch', 'drinks'],
#   'polarity': ['neutral', 'neutral', 'neutral']},
#  261: {'id': '3217',
#   'text': 'quite frankly , worst sushi ever tried .',
#   'term': ['sushi'],
#   'polarity': ['negative']},
#  262: {'id': '1188',
#   'text': 'food great , service ok .',
#   'term': ['food', 'service'],
#   'polarity': ['positive', 'neutral']},
#  263: {'id': '1973',
#   'text': 'overall pricetag expensive , something expect .',
#   'term': ['pricetag'],
#   'polarity': ['negative']},
#  264: {'id': '2392',
#   'text': 'spice great thaifood , love inexpensive appetizers .',
#   'term': ['thaifood', 'appetizers'],
#   'polarity': ['positive', 'positive']},
#  265: {'id': '925',
#   'text': 'service attentive .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  266: {'id': '1828',
#   'text': 'not makes homemade mozzarella , every pie ultra fresh .',
#   'term': ['mozzarella', 'pie'],
#   'polarity': ['positive', 'positive']},
#  267: {'id': '2363',
#   'text': 'fish overdone .',
#   'term': ['fish'],
#   'polarity': ['negative']},
#  268: {'id': '2831',
#   'text': "'re sitting maindiningroom ( spectacular , hand-painted high ceiling ) 'd never know world outside .",
#   'term': ['maindiningroom', 'ceiling'],
#   'polarity': ['positive', 'positive']},
#  269: {'id': '2479',
#   'text': 'visited bread bar january restaurant week pleased menuselections service .',
#   'term': ['menuselections', 'service'],
#   'polarity': ['positive', 'positive']},
#  270: {'id': '985',
#   'text': 'also make sure pay attention music piped - quite weird selection .',
#   'term': ['music'],
#   'polarity': ['neutral']},
#  271: {'id': '1843',
#   'text': 'establishment scores big points presentation style .',
#   'term': ['establishment'],
#   'polarity': ['positive']},
#  272: {'id': '2102',
#   'text': 'rest dimsum , though pricey chinatown standards , worth .',
#   'term': ['dimsum'],
#   'polarity': ['conflict']},
#  273: {'id': '2149',
#   'text': 'good food .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  274: {'id': '964',
#   'text': 'waitstaff friendly , not overly efficient .',
#   'term': ['waitstaff'],
#   'polarity': ['positive']},
#  275: {'id': '766',
#   'text': 'dimsum however good .',
#   'term': ['dimsum'],
#   'polarity': ['positive']},
#  276: {'id': '2501',
#   'text': 'service always friendly efficient .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  277: {'id': '2222',
#   'text': 'went combination different seafooddishes appetizers .',
#   'term': ['seafooddishes', 'appetizers'],
#   'polarity': ['neutral', 'neutral']},
#  278: {'id': '2786',
#   'text': 'great place casual date entertain clients lunch .',
#   'term': ['lunch'],
#   'polarity': ['neutral']},
#  279: {'id': '773',
#   'text': 'received apology left see show without dinner .',
#   'term': ['dinner'],
#   'polarity': ['neutral']},
#  280: {'id': '368',
#   'text': 'table next us asked crushed grapes long overdue bottleofwine finally arrived .',
#   'term': ['bottleofwine', 'grapes'],
#   'polarity': ['neutral', 'neutral']},
#  281: {'id': '994',
#   'text': 'prices good .',
#   'term': ['prices'],
#   'polarity': ['positive']},
#  282: {'id': '366',
#   'text': "could not catch waiter 's eye , ignored us .",
#   'term': ['waiter'],
#   'polarity': ['negative']},
#  283: {'id': '1270',
#   'text': "plain simple 's bad thaifood .",
#   'term': ['thaifood'],
#   'polarity': ['negative']},
#  284: {'id': '2097',
#   'text': 'usually 3 vs. 4 items per dish .',
#   'term': ['dish'],
#   'polarity': ['neutral']},
#  285: {'id': '1705',
#   'text': 'certain staples excellent ( burger , pastas ) , food not really point .',
#   'term': ['burger', 'pastas', 'food', 'staples'],
#   'polarity': ['positive', 'positive', 'neutral', 'positive']},
#  286: {'id': '3145',
#   'text': 'dimsum so-so , not spectacular .',
#   'term': ['dimsum'],
#   'polarity': ['neutral']},
#  287: {'id': '790',
#   'text': 'food so-so .',
#   'term': ['food'],
#   'polarity': ['neutral']},
#  288: {'id': '9',
#   'text': 'waitress , seems concerned looking good actually waitressing .',
#   'term': ['waitress'],
#   'polarity': ['negative']},
#  289: {'id': '3085',
#   'text': 'place larger features adequate seating unlike joints , bar deserves mention .',
#   'term': ['seating', 'bar', 'place'],
#   'polarity': ['positive', 'positive', 'positive']},
#  290: {'id': '1933',
#   'text': "threw fiance 's surprise 30th birthday dinner could n't happier .",
#   'term': ['dinner'],
#   'polarity': ['neutral']},
#  291: {'id': '1817',
#   'text': 'food-awesome .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  292: {'id': '2512',
#   'text': 'good music , great food , speedy service affordable prices .',
#   'term': ['music', 'food', 'service', 'prices'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  293: {'id': '1749',
#   'text': 'small wait , shorter expected .',
#   'term': ['wait'],
#   'polarity': ['conflict']},
#  294: {'id': '3441',
#   'text': 'lobstersandwich $ 24 although good not nearly enough warrant price .',
#   'term': ['lobstersandwich', 'price'],
#   'polarity': ['conflict', 'negative']},
# ...
#   'text': 'food consistant years never lets .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  905: {'id': '1029',
#   'text': 'found variety sashimiplate satisfying - fresh yummy .',
#   'term': ['sashimiplate'],
#   'polarity': ['positive']},
#  906: {'id': '3470',
#   'text': "forget read , atmosphere n't bad either .",
#   'term': ['atmosphere'],
#   'polarity': ['neutral']},
#  907: {'id': '163',
#   'text': "could n't carry conversation routinely interrupted waitress servants asking us order hinting 're taking much time -- amazing , sat .",
#   'term': ['waitress', 'servants'],
#   'polarity': ['negative', 'negative']},
#  908: {'id': '1017',
#   'text': 'sometimes get good food ok service .',
#   'term': ['food', 'service'],
#   'polarity': ['positive', 'neutral']},
#  909: {'id': '757',
#   'text': "'s place people pay lot mediocre food , noise chance fellow bridge tunnel folks .",
#   'term': ['food', 'noise'],
#   'polarity': ['neutral', 'negative']},
#  910: {'id': '472',
#   'text': "complaining chickendish , manager came tell us , no one ever complained , n't know dish supposed taste like .",
#   'term': ['chickendish', 'manager', 'dish'],
#   'polarity': ['negative', 'negative', 'neutral']},
#  911: {'id': '2223',
#   'text': 'food spicy delicious .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  912: {'id': '1339',
#   'text': 'went late weekday lunch .',
#   'term': ['lunch'],
#   'polarity': ['neutral']},
#  913: {'id': '3649',
#   'text': 'bartender unable tear away friends bar .',
#   'term': ['bartender', 'bar'],
#   'polarity': ['negative', 'neutral']},
#  914: {'id': '1140',
#   'text': "anyways , 're neighborhood eat good food , would n't waste time trying find something , rather go across street tamari .",
#   'term': ['food'],
#   'polarity': ['positive']},
#  915: {'id': '2337',
#   'text': 'dahkin also offers prixfixelunch buffet .',
#   'term': ['prixfixelunch', 'buffet'],
#   'polarity': ['positive', 'positive']},
#  916: {'id': '1174',
#   'text': "although place could little eye catching roomier , time , n't really matter .",
#   'term': ['place'],
#   'polarity': ['conflict']},
#  917: {'id': '2818',
#   'text': "frist time cafe st. bart 's must say delicous food service .",
#   'term': ['food', 'service'],
#   'polarity': ['positive', 'positive']},
#  918: {'id': '162',
#   'text': 'went double date friend girlfriend drinks appetizers .',
#   'term': ['drinks', 'appetizers'],
#   'polarity': ['neutral', 'neutral']},
#  919: {'id': '1216',
#   'text': 'great place grab hotbagel way work .',
#   'term': ['hotbagel'],
#   'polarity': ['positive']},
#  920: {'id': '3530',
#   'text': "'s like took leftover chicken , poured oil sprinkled pepperpowder ( sauce translucent red ) .",
#   'term': ['chicken', 'oil', 'pepperpowder', 'sauce'],
#   'polarity': ['negative', 'neutral', 'neutral', 'negative']},
#  921: {'id': '951',
#   'text': "one would think 'd get apology complimentary drinks - instead , got snobby waiter would n't even take order 15 minutes gave us lip asked .",
#   'term': ['waiter', 'drinks'],
#   'polarity': ['negative', 'neutral']},
#  922: {'id': '1304',
#   'text': 'actually gave 10 % tip ( never done despite mediocre food service ) , felt totally ripped .',
#   'term': ['food', 'service', 'tip'],
#   'polarity': ['neutral', 'neutral', 'negative']},
#  923: {'id': '1856',
#   'text': 'looking forward nice glassofsangria arrived .',
#   'term': ['glassofsangria'],
#   'polarity': ['positive']},
#  924: {'id': '3318',
#   'text': 'would highly recommand requesting tablebythewindow .',
#   'term': ['tablebythewindow'],
#   'polarity': ['positive']},
#  925: {'id': '1335',
#   'text': 'enjoyed food , highly disappointed poor service ( waiter not quite competent slow service ) lack remorse .',
#   'term': ['food', 'service', 'waiter', 'service'],
#   'polarity': ['positive', 'negative', 'negative', 'negative']},
#  926: {'id': '401',
#   'text': 'service , however , bright flower garden .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  927: {'id': '2944',
#   'text': "'ve grocery three times not item menu disappointed .",
#   'term': ['menu'],
#   'polarity': ['positive']},
#  928: {'id': '3298',
#   'text': "food good part , 's regular food , nothing special .",
#   'term': ['food', 'food'],
#   'polarity': ['positive', 'neutral']},
#  929: {'id': '1344',
#   'text': 'touch jalapeno heat contrast would good indeed .',
#   'term': ['jalapeno'],
#   'polarity': ['positive']},
#  930: {'id': '1381',
#   'text': "tried padseeew recommendation last reviewer since 's one favorite dishes .",
#   'term': ['padseeew', 'dishes'],
#   'polarity': ['neutral', 'positive']},
#  931: {'id': '3658',
#   'text': "ate backpatio , worth 's cool music hear well .",
#   'term': ['backpatio', 'music'],
#   'polarity': ['positive', 'positive']},
#  932: {'id': '1840',
#   'text': 'location perfect .',
#   'term': ['location'],
#   'polarity': ['positive']},
#  933: {'id': '2702',
#   'text': "guacamole+shrimpappetizer really great , filet , good , n't much like frites came , filet good , neither us cared .",
#   'term': ['guacamole+shrimpappetizer', 'filet', 'frites', 'filet'],
#   'polarity': ['positive', 'positive', 'negative', 'positive']},
#  934: {'id': '3536',
#   'text': 'lunchspecial asbolute steal .',
#   'term': ['lunchspecial'],
#   'polarity': ['positive']},
#  935: {'id': '1363',
#   'text': 'food asian-air fusion .',
#   'term': ['food'],
#   'polarity': ['neutral']},
#  936: {'id': '1065',
#   'text': 'nothing fancy really good food pretty reasonable price .',
#   'term': ['food', 'price'],
#   'polarity': ['positive', 'positive']},
#  937: {'id': '2137',
#   'text': 'thechickenpotpie excpetiona , cheeseburger huge delictable , service professional wan warm .',
#   'term': ['thechickenpotpie', 'cheeseburger', 'service'],
#   'polarity': ['positive', 'positive', 'positive']},
#  938: {'id': '2884',
#   'text': "quite liked food ambience , 'm not quite sure really deserve michelin rating displayed prooudly window .",
#   'term': ['food', 'ambience'],
#   'polarity': ['positive', 'positive']},
#  939: {'id': '558',
#   'text': 'italian employees may not speak best english adds experience .',
#   'term': ['employees'],
#   'polarity': ['conflict']},
#  940: {'id': '1099',
#   'text': 'dinner brunch .',
#   'term': ['dinner', 'brunch'],
#   'polarity': ['neutral', 'neutral']},
#  941: {'id': '2042',
#   'text': 'not worth prices .',
#   'term': ['prices'],
#   'polarity': ['negative']},
#  942: {'id': '1114',
#   'text': 'moment enter till moment walk friendly helpful staff fantastic .',
#   'term': ['staff'],
#   'polarity': ['positive']},
#  943: {'id': '233',
#   'text': 'service good food wonderful .',
#   'term': ['service', 'food'],
#   'polarity': ['positive', 'positive']},
#  944: {'id': '3276',
#   'text': 'gets 10 excellent service advice .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  945: {'id': '960',
#   'text': 'restaurant bit noisy something overlooked sit enjoy great meal',
#   'term': ['meal'],
#   'polarity': ['positive']},
#  946: {'id': '3555',
#   'text': 'fan spicyethnicfoods , indian included , made friends place long ago .',
#   'term': ['spicyethnicfoods'],
#   'polarity': ['positive']},
#  947: {'id': '2477',
#   'text': 'say snacking really not set proper dinner .',
#   'term': ['dinner', 'snacking'],
#   'polarity': ['negative', 'neutral']},
#  948: {'id': '1095',
#   'text': 'qualityoffood restaurant accompanied fantastic livejazz makes place perfect 10 !',
#   'term': ['qualityoffood', 'livejazz'],
#   'polarity': ['positive', 'positive']},
#  949: {'id': '696',
#   'text': 'eaten saul , many times , food always consistently , outrageously good .',
#   'term': ['food'],
#   'polarity': ['positive']},
#  950: {'id': '62',
#   'text': '( always ask bartender seasonalbeer ! ! !',
#   'term': ['seasonalbeer', 'bartender'],
#   'polarity': ['positive', 'neutral']},
#  951: {'id': '768',
#   'text': "visiting , 'll enjoy ambiance fact 's time sq ...",
#   'term': ['ambiance'],
#   'polarity': ['positive']},
#  952: {'id': '3636',
#   'text': 'way back nj , since ny , figured not grab food ?',
#   'term': ['food'],
#   'polarity': ['neutral']},
#  953: {'id': '3695',
#   'text': 'sandwiches tho pricey stuffed - serve 2 persons easily thus cost effective !',
#   'term': ['sandwiches'],
#   'polarity': ['conflict']},
#  954: {'id': '211',
#   'text': 'service food one would expect spending type money .',
#   'term': ['service', 'food'],
#   'polarity': ['neutral', 'neutral']},
#  955: {'id': '524',
#   'text': 'love atmosphere - felt like paris .',
#   'term': ['atmosphere'],
#   'polarity': ['positive']},
#  956: {'id': '801',
#   'text': 'every course better next .',
#   'term': ['course'],
#   'polarity': ['positive']},
#  957: {'id': '266',
#   'text': 'staff incredibly helpful attentive .',
#   'term': ['staff'],
#   'polarity': ['positive']},
#  958: {'id': '1986',
#   'text': 'presentation service thing , magic show works .',
#   'term': ['service'],
#   'polarity': ['positive']},
#  959: {'id': '1240',
#   'text': 'apparently , good cook works .',
#   'term': ['cook'],
#   'polarity': ['positive']},
#  960: {'id': '1787',
#   'text': 'yellowtail particularly good well .',
#   'term': ['yellowtail'],
#   'polarity': ['positive']},
#  961: {'id': '2349',
#   'text': 'ate clamsoreganta spectacular saladwithperfectlymarinatedcucumbersandtomatoeswithlotsofshrimpandbasil .',
#   'term': ['clamsoreganta',
#    'saladwithperfectlymarinatedcucumbersandtomatoeswithlotsofshrimpandbasil'],
#   'polarity': ['positive', 'positive']},
#  962: {'id': '2485',
#   'text': 'menu changed , portions even smaller , lentildish salty beyond edibility , basmatiricedish lacked flavor .',
#   'term': ['menu', 'portions', 'lentildish', 'basmatiricedish', 'flavor'],
#   'polarity': ['negative', 'negative', 'negative', 'negative', 'negative']},
#  963: {'id': '2412',
#   'text': 'spice sleek , modern cool menu not hurt wallet .',
#   'term': ['menu'],
#   'polarity': ['positive']},
#  964: {'id': '2647',
#   'text': 'patroon features nice cigarbar great staff .',
#   'term': ['cigarbar', 'staff'],
#   'polarity': ['positive', 'positive']},
#  965: {'id': '714',
#   'text': 'affordable excellent ambient !',
#   'term': ['ambient'],
#   'polarity': ['positive']},
#  966: {'id': '3002',
#   'text': 'important , sushi rivals best tokyo .',
#   'term': ['sushi'],
#   'polarity': ['positive']},
#  967: {'id': '2616',
#   'text': 'never cheescake like .',
#   'term': ['cheescake'],
#   'polarity': ['positive']},
#  968: {'id': '2969',
#   'text': 'bill little high , worth .',
#   'term': ['bill'],
#   'polarity': ['conflict']},
#  969: {'id': '2410',
#   'text': 'co-workers wait almost hour delivery , discover got not ordered .',
#   'term': ['delivery'],
#   'polarity': ['negative']},
#  970: {'id': '3206',
#   'text': 'go-to dates well entertaining town guests .',
#   'term': ['entertaining'],
#   'polarity': ['positive']},
#  971: {'id': '837',
#   'text': 'people rave ambience .',
#   'term': ['ambience'],
#   'polarity': ['negative']},
#  972: {'id': '1244',
#   'text': 'meeting friends drink lafayette 161 happened walk thai angel famished .',
#   'term': ['drink'],
#   'polarity': ['neutral']},
#  973: {'id': '1343',
#   'text': "flukesashimi drizzled jalapeno-limeoliveoil , fruitoftheoil nicely highlighting fish 's sweetness .",
#   'term': ['flukesashimi', 'jalapeno-limeoliveoil', 'fruitoftheoil', 'fish'],
#   'polarity': ['positive', 'positive', 'positive', 'positive']},
#  974: {'id': '348',
#   'text': 'great sushi experience .',
#   'term': ['sushi'],
#   'polarity': ['positive']},
#  975: {'id': '1956',
#   'text': "'re looking great meal decent price , go del frisco 's !",
#   'term': ['meal', 'price'],
#   'polarity': ['positive', 'positive']},
#  976: {'id': '2039',
#   'text': 'charge $ 6.00 rice .',
#   'term': ['rice'],
#   'polarity': ['negative']},
#  977: {'id': '2990',
#   'text': "steakaupoivre one worst 've .",
#   'term': ['steakaupoivre'],
#   'polarity': ['negative']},
#  978: {'id': '1779',
#   'text': 'owner staff japanese well adds entire ambiance .',
#   'term': ['staff', 'ambiance', 'owner'],
#   'polarity': ['positive', 'positive', 'positive']},
#  979: {'id': '142',
#   'text': 'try congee donutlikedeepfrieddoughtheycallowleysoh , delicious sweet tasting bread .',
#   'term': ['congee', 'bread', 'donutlikedeepfrieddoughtheycallowleysoh'],
#   'polarity': ['positive', 'positive', 'positive']},
#  980: {'id': '2768',
#   'text': 'although tables may closely situated , candle-light , food-quality service overcompensate .',
#   'term': ['candle-light', 'food-quality', 'service', 'tables'],
#   'polarity': ['positive', 'positive', 'positive', 'negative']},
#  981: {'id': '812',
#   'text': 'food delicious waiter incredibly helpful attentive ( considering ones first hour ) .',
#   'term': ['food', 'waiter'],
#   'polarity': ['positive', 'positive']},
#  982: {'id': '218',
#   'text': 'spectacular caviar hospitable waitstaff , felt like royalty enjoyed every second .',
#   'term': ['caviar', 'waitstaff'],
#   'polarity': ['positive', 'positive']},
#  983: {'id': '1204',
#   'text': "perhaps food considered extreme upper east side resident , rest us 've actually eaten ethnicfood , simply dull .",
#   'term': ['food', 'ethnicfood'],
#   'polarity': ['conflict', 'negative']},
#  984: {'id': '811',
#   'text': 'place real empty first sunday ever opened .',
#   'term': ['place'],
#   'polarity': ['negative']},
#  985: {'id': '2239',
#   'text': 'little place definitely exceeded expectations sure get lot food money .',
#   'term': ['food', 'money', 'place'],
#   'polarity': ['positive', 'positive', 'conflict']},
#  986: {'id': '3493',
#   'text': 'ambience delightful , service impeccable .',
#   'term': ['ambience', 'service'],
#   'polarity': ['positive', 'positive']},
#  987: {'id': '503',
#   'text': 'service excellent , ac worked well ( thank god , hot ! ) .',
#   'term': ['service', 'ac'],
#   'polarity': ['positive', 'positive']},
#  988: {'id': '3236',
#   'text': 'get sense people care restaurant experience nice .',
#   'term': ['people'],
#   'polarity': ['positive']},
#  989: {'id': '1606',
#   'text': 'delicious , cooks friendly willing take moment speak shake hand .',
#   'term': ['cooks'],
#   'polarity': ['positive']},
#  990: {'id': '300',
#   'text': 'friend ordered special sushirolls excellent presentation tasted great !',
#   'term': ['sushirolls'],
#   'polarity': ['positive']},
#  991: {'id': '2334',
#   'text': 'although warned dinnermenutosit takeout prices different .',
#   'term': ['prices', 'dinnermenutosit', 'takeout'],
#   'polarity': ['neutral', 'neutral', 'neutral']},
#  992: {'id': '2079',
#   'text': 'staff accomodating , food absolutely delicious place lovely .',
#   'term': ['staff', 'food', 'place'],
#   'polarity': ['positive', 'positive', 'positive']},
#  993: {'id': '1424',
#   'text': "picks : - scallionpancake ( fried vegetablejuice , special tasty ) - guizhouchicken - shreddedsquidfamilystyle ( one personal favorites ) - sichuanspicysoftshellcrab - shuizhufish ( one hardcore sichuanfood fans , would n't recommend american friends 's spicy .",
#   'term': ['scallionpancake',
#    'vegetablejuice',
#    'guizhouchicken',
#    'shreddedsquidfamilystyle',
#    'sichuanspicysoftshellcrab',
#    'shuizhufish',
#    'sichuanfood'],
#   'polarity': ['positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'positive',
#    'neutral']},
#  994: {'id': '1294',
#   'text': 'smell like stuff old cannedvegetables like spinachmushroomcalzone .',
#   'term': ['spinachmushroomcalzone', 'cannedvegetables'],
#   'polarity': ['negative', 'negative']},
#  995: {'id': '2361',
#   'text': 'celebrate birthday , three us went mare anticipating great food .',
#   'term': ['food'],
#   'polarity': ['neutral']},
#  996: {'id': '316',
#   'text': 'great deal 6 bluepointoysters beer glassofwine $ 8 !',
#   'term': ['bluepointoysters', 'beer', 'glassofwine'],
#   'polarity': ['neutral', 'neutral', 'neutral']},
#  997: {'id': '1393',
#   'text': 'really liked noodledishes rice avenue compared greencurrydish .',
#   'term': ['noodledishes', 'greencurrydish'],
#   'polarity': ['positive', 'negative']},
#  998: {'id': '1317',
#   'text': 'whatever reason , prices twice high .',
#   'term': ['prices'],
#   'polarity': ['negative']},
#  999: {'id': '1213',
#   'text': 'relatively new area tried pick bgel 2nd disappointed service thought food overated pricey side .',
#   'term': ['service', 'food'],
#   'polarity': ['negative', 'negative']},
#  ...}

# %%
len(data_dict)
# Out:
# 2021

# %%
# Create ground truth list
ground_truth_list = []
for i in range(len(data_dict)):
    for j in range(len(data_dict[i]['polarity'])):
        if(data_dict[i]['polarity'][j]!='conflict'):
            ground_truth_list.append(data_dict[i]['polarity'][j])

# %%
print('Actual Number in Ground Truth:')
print('Number of Positive: ' + str(ground_truth_list.count('positive')))
print('Number of Neutral: ' + str(ground_truth_list.count('neutral')))
print('Number of Negative: ' + str(ground_truth_list.count('negative')))
# Out:
# Actual Number in Ground Truth:
# Number of Positive: 2164
# Number of Neutral: 633
# Number of Negative: 805

# %%
TextBlob('overripe').sentiment.polarity
# Out:
# 0.0

# %% [markdown]
# # 2. Dependency Parsing and Aspect Term Based Rules

# %%
# definition of polarity according to their value from Textblob
# Positive: 0.1 - 1.0
# Netural: 0.0 - 0.1
# Negative: -1.0 - 0.0

def polarity_define(value):
    if value <0:
        polarity = 'negative'
    elif value < 0.1:
        polarity = 'neutral'
    else:
        polarity = 'positive'
    return polarity

# %%
# function to calculate Recall and Precision
def Recall_Precision_Cal(predicted, actual, label):
    TP = 0
    FN = 0
    FP = 0
    
    for i in range(len(predicted)):
        if ((actual[i]== label) & (predicted[i]==label)):
            TP +=1
        if ((actual[i]== label) & (predicted[i]!=label)):
            FN +=1
        if ((actual[i]!= label) & (predicted[i]==label)):
            FP +=1
            
    Recall = TP/(TP+FN)
    Precision = TP/(TP+FP)
    return (float(format(Recall, ".4f")) , float(format(Precision, ".4f")))

# %% [markdown]
# ### Poisitive Rule 1 (General rule)

# %%
adjective_list = []
num = 0

for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    sen = nlp(sentence)
    for j in range(len(data_dict[i]['term'])):
        if(data_dict[i]['polarity'][j]!='conflict'):
            num += 1
            for token in sen:
                if str(token) == data_dict[i]['term'][j]:
                    head = token.head
                    children = [child for child in token.children]
            
            
            # Use aspect term's Head as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                            adjective_list.append(token)
                            
                            
            # Use aspect term's children as an adjective
            if(num > len(adjective_list)):
                for child in children:
                    for token in sen:
                        if(num > len(adjective_list)):
                            if(str(token)==str(child)):
                                if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                    adjective_list.append(token)
                                    break
            
            # Use aspect term's Head's children as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        head_children = [child for child in token.children]

                        for child in head_children:
                            for token in sen:
                                if(num > len(adjective_list)):
                                    if(str(token)==str(child)):
                                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                            adjective_list.append(token)
                                            break
            
                                                                                     
            # Find the adjective near the aspect term in sentence as adjective
            if(num > len(adjective_list)):
                fufill = False
                try:
                    index = sentence.split().index(str(data_dict[i]['term'][j]))
                    for k in range(index - 4, index + 4, 1):
                        if k >= 0 and k < len(sentence.split()):
                            if fufill == False:
                                if sen[k].dep =='amod' or sen[k].dep_ =='acomp' or sen[k].dep_=='advmod' or sen[k].pos_ == 'ADJ':
                                    adjective_list.append(sen[k])
                                    fufill = True
                except:
                    None
            
            # Others are treated it as Neutral
            if(num > len(adjective_list)):
                adjective_list.append('neutral')
                
pos1_score_list = [TextBlob(str(element)).sentiment.polarity for element in adjective_list]
pos1_predicted_list = [polarity_define(element) for element in pos1_score_list]
Recall_Precision_Cal(pos1_predicted_list, ground_truth_list, 'positive')
# Out:
# (0.5434, 0.8082)

# %%
print('Number of Positive: ' + str(pos1_predicted_list.count('positive')))
print('Number of Neutral: ' + str(pos1_predicted_list.count('neutral')))
print('Number of Negative: ' + str(pos1_predicted_list.count('negative')))
# Out:
# Number of Positive: 1455
# Number of Neutral: 1824
# Number of Negative: 323

# %%
adjective_list
# Out:
# [horrible,
#  redeeming,
#  exceptional,
#  capable,
#  menu,
#  outstanding,
#  outstanding,
#  favorite,
#  orrechietewithsausageandchicken,
#  half,
#  enough,
#  outstanding,
#  nevertheless,
#  mayonnaise,
#  mayonnaise,
#  cooked,
#  'neutral',
#  forgot,
#  cooked,
#  hot,
#  'neutral',
#  perfect,
#  good,
#  good,
#  expert,
#  best,
#  best,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  enough,
#  whole,
#  'neutral',
#  'neutral',
#  best,
#  friendly,
#  friendly,
#  little,
#  incredible,
#  warm,
#  friendly,
#  great,
#  great,
#  cute,
#  cute,
#  free,
#  poor,
#  poor,
#  good,
#  serious,
#  closer,
#  amazing,
#  excellent,
#  puffpastrygoatcheese,
#  puffpastrygoatcheese,
#  hangersteakaupoivre,
#  'neutral',
#  perfect,
#  curtious,
#  'neutral',
#  mild,
#  delicious,
#  little,
#  winelist,
#  best,
#  even,
#  detailed,
#  consistently,
#  great,
#  consistently,
#  nice,
#  pleasant,
#  pleasant,
#  really,
#  really,
#  'neutral',
#  fabulous,
#  fantastic,
#  chilled,
#  chilled,
#  'neutral',
#  'neutral',
#  great,
#  great,
#  great,
#  unpretensious,
#  romantic,
#  romantic,
#  'neutral',
#  generously,
#  generously,
#  great,
#  limited,
#  'neutral',
#  almost,
#  almost,
#  crazy,
#  great,
#  great,
#  pressured,
#  unfortunately,
#  delicious,
#  'neutral',
#  around,
#  first,
#  huge,
#  taiwanese,
#  hesititate,
#  efficient,
#  often,
#  amazed,
#  'neutral',
#  impecible,
#  impecible,
#  special,
#  friendly,
#  friendly,
#  good,
#  good,
#  packed,
#  good,
#  nice,
#  pre,
#  also,
#  half,
#  maybe,
#  entire,
#  strong,
#  lobstersandwich,
#  even,
#  worth,
#  soft,
#  good,
#  'neutral',
#  'neutral',
#  also,
#  also,
#  'neutral',
#  new,
#  evident,
#  evident,
#  precise,
#  new,
#  delicious,
#  delicious,
#  artisanal,
#  quite,
#  'neutral',
#  overall,
#  incredible,
#  'neutral',
#  terrible,
#  bland,
#  unaccommodating,
#  late,
#  late,
#  seated,
#  good,
#  classic,
#  impressed,
#  entire,
#  wonderful,
#  always,
#  highly,
#  regularly,
#  'neutral',
#  fantastic,
#  ocasionally,
#  crappy,
#  authentic,
#  authentic,
#  'neutral',
#  saved,
#  'neutral',
#  'neutral',
#  even,
#  even,
#  good,
#  right,
#  good,
#  dalbukhara,
#  forward,
#  back,
#  good,
#  fair,
#  'neutral',
#  happy,
#  'neutral',
#  average,
#  average,
#  average,
#  always,
#  fresh,
#  delicious,
#  great,
#  great,
#  great,
#  great,
#  'neutral',
#  forgotten,
#  'neutral',
#  overall,
#  heavy,
#  cheap,
#  cheap,
#  shredded,
#  excellent,
#  excellent,
#  friendly,
#  'neutral',
#  great,
#  first,
#  odd,
#  oily,
#  good,
#  good,
#  varietyoffish,
#  fresh,
#  favorite,
#  favorite,
#  good,
#  favorite,
#  beveragemanager,
#  beveragemanager,
#  funky,
#  funky,
#  clearly,
#  clearly,
#  clearly,
#  late,
#  'neutral',
#  alluring,
#  romantic,
#  authentic,
#  authentic,
#  complicated,
#  complicated,
#  complicated,
#  back,
#  'neutral',
#  'neutral',
#  smaller,
#  best,
#  atmorphere,
#  'neutral',
#  right,
#  threecoursemeal,
#  outstanding,
#  romantic,
#  romantic,
#  pathetic,
#  'neutral',
#  high,
#  'neutral',
#  sticky,
#  sticky,
#  proper,
#  far,
#  frankly,
#  hostess,
#  great,
#  'neutral',
#  narrow,
#  tiny,
#  tiny,
#  small,
#  small,
#  great,
#  precisely,
#  accompanied,
#  accompanied,
#  pickelsandslaw,
#  pickelsandslaw,
#  decent,
#  reasonable,
#  conveniently,
#  even,
#  rather,
#  always,
#  also,
#  'neutral',
#  wonderful,
#  exceptional,
#  atrocious,
#  'neutral',
#  'neutral',
#  'neutral',
#  anti,
#  especially,
#  calamari,
#  'neutral',
#  well,
#  well,
#  'neutral',
#  'neutral',
#  particular,
#  'neutral',
#  special,
#  'neutral',
#  particular,
#  'neutral',
#  'neutral',
#  'neutral',
#  fresh,
#  fresh,
#  fresh,
#  enough,
#  good,
#  awful,
#  'neutral',
#  'neutral',
#  'neutral',
#  experienced,
#  hostess,
#  good,
#  good,
#  different,
#  happy,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  chocolatebreadpudding,
#  chocolatebreadpudding,
#  'neutral',
#  'neutral',
#  good,
#  good,
#  workers,
#  impeccable,
#  impeccable,
#  present,
#  present,
#  best,
#  great,
#  though,
#  'neutral',
#  'neutral',
#  ever,
#  still,
#  away,
#  away,
#  next,
#  'neutral',
#  amazing,
#  good,
#  'neutral',
#  outstanding,
#  outstanding,
#  promptly,
#  slow,
#  friendly,
#  friendly,
#  small,
#  good,
#  'neutral',
#  comparable,
#  highly,
#  wonderful,
#  wonderful,
#  intimate,
#  fun,
#  great,
#  great,
#  'neutral',
#  cool,
#  colorful,
#  worth,
#  enough,
#  enough,
#  'neutral',
#  worst,
#  completely,
#  worst,
#  neighborhood-,
#  bad,
#  good,
#  good,
#  'neutral',
#  outside,
#  good,
#  good,
#  40pp,
#  friendly,
#  dimsum,
#  based,
#  extra,
#  extra,
#  extra,
#  'neutral',
#  finally,
#  'neutral',
#  fresh,
#  hot,
#  'neutral',
#  good,
#  even,
#  moderately,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  friendly,
#  friendly,
#  sake,
#  terrific,
#  terrific,
#  amazing,
#  fresh,
#  'neutral',
#  quickly,
#  'neutral',
#  quick,
#  'neutral',
#  snappy,
#  'neutral',
#  unbearable,
#  perfect,
#  recommended,
#  recommended,
#  earlier,
#  great,
#  odd,
#  'neutral',
#  back,
#  much,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  subpar,
#  berate,
#  wrong,
#  expensive,
#  subpar,
#  great,
#  incredible,
#  nice,
#  winelist,
#  winelist,
#  winelist,
#  expected,
#  expected,
#  ordered,
#  ordered,
#  'neutral',
#  especially,
#  especially,
#  especially,
#  'neutral',
#  'neutral',
#  beautiful,
#  pretty,
#  starving,
#  great,
#  great,
#  best,
#  outstanding,
#  approximately,
#  approximately,
#  'neutral',
#  worst,
#  great,
#  great,
#  overall,
#  great,
#  inexpensive,
#  'neutral',
#  homemade,
#  fresh,
#  'neutral',
#  spectacular,
#  spectacular,
#  'neutral',
#  'neutral',
#  sure,
#  big,
#  good,
#  friendly,
#  good,
#  efficient,
#  different,
#  different,
#  'neutral',
#  'neutral',
#  overdue,
#  crushed,
#  good,
#  'neutral',
#  bad,
#  'neutral',
#  certain,
#  excellent,
#  excellent,
#  excellent,
#  spectacular,
#  so,
#  concerned,
#  adequate,
#  'neutral',
#  larger,
#  happier,
#  'neutral',
#  good,
#  great,
#  speedy,
#  affordable,
#  enough,
#  always,
#  salty,
#  unavailable,
#  unavailable,
#  unavailable,
#  excellent,
#  excellent,
#  hostess,
#  hostess,
#  simple,
#  else,
#  'neutral',
#  'neutral',
#  light,
#  nice,
#  nice,
#  good,
#  great,
#  great,
#  nice,
#  excellent,
#  excellent,
#  excellent,
#  actually,
#  better,
#  a++,
#  good,
#  awesome,
#  definitely,
#  corriander,
#  good,
#  best,
#  sometime,
#  nice,
#  ordered,
#  ordered,
#  comparable,
#  comparable,
#  amazing,
#  amazing,
#  great,
#  good,
#  favorite,
#  good,
#  even,
#  good,
#  crowded,
#  'neutral',
#  'neutral',
#  nicest,
#  also,
#  cool,
#  low,
#  spectacular,
#  waitstaff,
#  waitstaff,
#  swordfish,
#  romantic,
#  terrible,
#  great,
#  fast,
#  fast,
#  excellent,
#  'neutral',
#  sort,
#  outstanding,
#  outstanding,
#  mizu,
#  solid,
#  nice,
#  nice,
#  often,
#  times-,
#  times-,
#  excellent,
#  excellent,
#  'neutral',
#  cheap,
#  literally,
#  amazing,
#  good,
#  amazing,
#  usually,
#  usually,
#  winelist,
#  winelist,
#  high,
#  extra,
#  expensive,
#  expensive,
#  expensive,
#  really,
#  available,
#  available,
#  waitress,
#  phenomenal,
#  nice,
#  great,
#  solid,
#  solid,
#  adventurous,
#  adventurous,
#  always,
#  even,
#  'neutral',
#  even,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  good,
#  otherwise,
#  'neutral',
#  'neutral',
#  forward,
#  'neutral',
#  great,
#  regular,
#  'neutral',
#  friendly,
#  regular,
#  diner,
#  diner,
#  thoroughly,
#  always,
#  large,
#  different,
#  delicious,
#  tasty,
#  great,
#  good,
#  friendly,
#  'neutral',
#  romantic,
#  heavy,
#  reasonably,
#  tasty,
#  tasty,
#  'neutral',
#  excellent,
#  regular,
#  nice,
#  obviously,
#  better,
#  great,
#  great,
#  great,
#  better,
#  lovely,
#  expensive,
#  authentic,
#  ever,
#  cold,
#  'neutral',
#  really,
#  great,
#  'neutral',
#  ago,
#  impressed,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  impressive,
#  impressive,
#  'neutral',
#  'neutral',
#  really,
#  authentic,
#  good,
#  good,
#  good,
#  good,
#  higher,
#  higher,
#  amazing,
#  better,
#  sweet,
#  tiny,
#  good,
#  'neutral',
#  great,
#  beersontap,
#  excellent,
#  beersontap,
#  well,
#  blasted,
#  least,
#  amazing,
#  metrazur,
#  friendly,
#  actually,
#  quickly,
#  excellent,
#  excellent,
#  excellent,
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  drafty,
#  little,
#  appetizing,
#  appetizing,
#  big,
#  fresh,
#  reasonably,
#  interesting,
#  'neutral',
#  'neutral',
#  'neutral',
#  fabulous,
#  'neutral',
#  available,
#  good,
#  overall,
#  typical,
#  good,
#  great,
#  'neutral',
#  great,
#  pre,
#  pre,
#  busier,
#  crowded,
#  inducing,
#  always,
#  beautiful,
#  beautiful,
#  amazing,
#  good,
#  great,
#  tasty,
#  first,
#  'neutral',
#  first,
#  also,
#  top,
#  'neutral',
#  cool,
#  authentic,
#  authentic,
#  'neutral',
#  great,
#  great,
#  good,
#  wonderful,
#  back,
#  waitstaff,
#  back,
#  delicious,
#  beautiful,
#  many,
#  dessertswithfrogjelly,
#  dessertswithfrogjelly,
#  great,
#  great,
#  definitely,
#  always,
#  always,
#  several,
#  authentic,
#  even,
#  late,
#  delicious,
#  disappointment,
#  delicious,
#  delicious,
#  'neutral',
#  freshmozzcheese,
#  freshmozzcheese,
#  freshmozzcheese,
#  freshmozzcheese,
#  better,
#  imported,
#  quickly,
#  new,
#  new,
#  'neutral',
#  fancy,
#  phenomenal,
#  phenomenal,
#  terrible,
#  unfortunately,
#  fresh,
#  filetmignonwithgarlicmash,
#  specifically,
#  theatermenu,
#  marvelous,
#  'neutral',
#  attentive,
#  tasty,
#  tasty,
#  however,
#  actually,
#  however,
#  large,
#  large,
#  'neutral',
#  helpful,
#  busy,
#  really,
#  tasty,
#  new,
#  genuinely,
#  truly,
#  real,
#  nice,
#  nice,
#  pleasurable,
#  always,
#  pleasurable,
#  certainly,
#  certainly,
#  'neutral',
#  'neutral',
#  better,
#  cornerboothtable,
#  cornerboothtable,
#  great,
#  basically,
#  basically,
#  good,
#  real,
#  squid,
#  squid,
#  terrific,
#  terrific,
#  especially,
#  'neutral',
#  'neutral',
#  'neutral',
#  delighted,
#  delighted,
#  incredible,
#  delicious,
#  good,
#  amazing,
#  absolutely,
#  amazing,
#  ever,
#  tasty,
#  tasty,
#  largewholeshrimp,
#  largewholeshrimp,
#  reliable,
#  reliable,
#  great,
#  great,
#  great,
#  great,
#  cool,
#  really,
#  cool,
#  cool,
#  indian,
#  usually,
#  great,
#  excited,
#  loud,
#  loud,
#  good,
#  good,
#  good,
#  perfect,
#  icecream,
#  icecream,
#  icecream,
#  icecream,
#  'neutral',
#  good,
#  certainly,
#  friendly,
#  fabulous,
#  awesome,
#  fabulous,
#  fabulous,
#  fantastic,
#  own,
#  also,
#  blowing,
#  good,
#  porkbelly,
#  fat,
#  twice,
#  close,
#  nice,
#  beautiful,
#  cheap,
#  'neutral',
#  friendly,
#  'neutral',
#  really,
#  dressed,
#  dressed,
#  'neutral',
#  excellent,
#  'neutral',
#  'neutral',
#  cold,
#  cold,
#  creative,
#  'neutral',
#  'neutral',
#  good,
#  small,
#  cheap,
#  cheap,
#  'neutral',
#  whenever,
#  great,
#  whenever,
#  sweet,
#  empty,
#  though,
#  even,
#  limited,
#  ultra,
#  outdooratmosphere,
#  large,
#  best,
#  great,
#  great,
#  reasonable,
#  aunthentic,
#  'neutral',
#  expensive,
#  ordinary,
#  ordinary,
#  delicious,
#  delicious,
#  steak,
#  fabulous,
#  'neutral',
#  twice,
#  actually,
#  'neutral',
#  twice,
#  'neutral',
#  'neutral',
#  inconsistent,
#  also,
#  much,
#  extra,
#  'neutral',
#  much,
#  much,
#  pathetic,
#  big,
#  vibrant,
#  dininghall,
#  dininghall,
#  quick,
#  slow,
#  officelunch,
#  forgettable,
#  excellent,
#  excellent,
#  forgettable,
#  bistrofare,
#  'neutral',
#  'neutral',
#  best,
#  best,
#  best,
#  high,
#  high,
#  good,
#  reasonable,
#  greeted,
#  gracious,
#  considerably,
#  adorn,
#  still,
#  reasonable,
#  offerng,
#  small,
#  offerng,
#  offerng,
#  'neutral',
#  also,
#  instantly,
#  'neutral',
#  'neutral',
#  perfect,
#  perfect,
#  though,
#  'neutral',
#  ...]

# %% [markdown]
# ### Poisitive Rule 2 (if the sentence contains some positive words, then sentiment of aspect terms will become positive)

# %%
# Create a positive word list (polarity of these words are zero under Textblob)
positive_word_list = ['accomplishes', 'admire', 'best','affordable','amazed', 'amuse','relax','relaxed','relaxing','award','like','chill', 'diverse','chilled','complementary','entertain' ,'entertaining', 'entertainment', 'timely', 'toasted', 'complete', 'completed', 'amazing', 'wonderful', 'fantastic', 'incredible', 'yummy']

# additional score for having above positive words (most of them are non-adjective and have zero score under Textblob)
pos_rule_1_score_add = []
for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    add_score = 0
    for j in range(len(data_dict[i]['term'])):
        for k in range(len(positive_word_list)):
            if sentence.split().count(positive_word_list[k]):
                add_score += 0.1
        pos_rule_1_score_add.append(add_score)
        

zipped_lists = zip(pos1_score_list, pos_rule_1_score_add)
pos2_score_list = [x + y for (x, y) in zipped_lists]
pos2_predicted_list = [polarity_define(element) for element in pos2_score_list]
Recall_Precision_Cal(pos2_predicted_list, ground_truth_list, 'positive')
# Out:
# (0.6109, 0.7507)

# %%
print('Number of Positive: ' + str(pos2_predicted_list.count('positive')))
print('Number of Neutral: ' + str(pos2_predicted_list.count('neutral')))
print('Number of Negative: ' + str(pos2_predicted_list.count('negative')))
# Out:
# Number of Positive: 1761
# Number of Neutral: 1533
# Number of Negative: 308

# %% [markdown]
# ### Poisitive Rule 3 (Negate words around negative words)

# %%
num = -1
negate_list = []
for i in range(len(data_dict)):
    sentence = original_data_dict[i]['text']
    sen = nlp(sentence)
    for j in range(len(data_dict[i]['term'])):
        negate_flag = 0
        if(data_dict[i]['polarity'][j]!='conflict'):
            num += 1
            
            # detect if the adjective is a negative word or a neutral word
            if TextBlob(str(adjective_list[num])).sentiment.polarity <= 0:
                try:
                    index = sentence.split().index(str(adjective_list[num]))
                    for k in range(index- 5, index + 5 , 1):
                        if k >= 0 and k < len(sentence.split()):
                            if sen[k].dep_=='neg': 
                                negate_flag = 1
                except:
                    None
                
                negate_list.append(negate_flag)
            else:
                
                negate_list.append(negate_flag)
                
zipped_lists = zip(pos2_score_list, negate_list)
pos3_score_list = [x + y for (x, y) in zipped_lists]
pos3_predicted_list = [polarity_define(element) for element in pos3_score_list]
Recall_Precision_Cal(pos3_predicted_list, ground_truth_list, 'positive')
# Out:
# (0.622, 0.7299)

# %%
print('Number of Positive: ' + str(pos3_predicted_list.count('positive')))
print('Number of Neutral: ' + str(pos3_predicted_list.count('neutral')))
print('Number of Negative: ' + str(pos3_predicted_list.count('negative')))
# Out:
# Number of Positive: 1844
# Number of Neutral: 1484
# Number of Negative: 274

# %% [markdown]
# ### Neutral Rule #1 (General rule)

# %%
adjective_list = []
num = 0

for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    sen = nlp(sentence)
    for j in range(len(data_dict[i]['term'])):
        if(data_dict[i]['polarity'][j]!='conflict'):
            num += 1
            for token in sen:
                if str(token) == data_dict[i]['term'][j]:
                    head = token.head
                    children = [child for child in token.children]
            
            
            # Use aspect term's Head as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                            adjective_list.append(token)
                            
                            
            # Use aspect term's children as an adjective
            if(num > len(adjective_list)):
                for child in children:
                    for token in sen:
                        if(num > len(adjective_list)):
                            if(str(token)==str(child)):
                                if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                    adjective_list.append(token)
                                    break
            
            # Use aspect term's Head's children as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        head_children = [child for child in token.children]

                        for child in head_children:
                            for token in sen:
                                if(num > len(adjective_list)):
                                    if(str(token)==str(child)):
                                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                            adjective_list.append(token)
                                            break
            
                                                                                     
            # Find the adjective near the aspect term in sentence as adjective
            if(num > len(adjective_list)):
                fufill = False
                try:
                    index = sentence.split().index(str(data_dict[i]['term'][j]))
                    for k in range(index - 4, index + 4, 1):
                        if k >= 0 and k < len(sentence.split()):
                            if fufill == False:
                                if sen[k].dep =='amod' or sen[k].dep_ =='acomp' or sen[k].dep_=='advmod' or sen[k].pos_ == 'ADJ':
                                    adjective_list.append(sen[k])
                                    fufill = True
                except:
                    None
            
            # Others are treated it as Neutral
            if(num > len(adjective_list)):
                adjective_list.append('neutral')

                
neu1_score_list = [TextBlob(str(element)).sentiment.polarity for element in adjective_list]
neu1_predicted_list = [polarity_define(element) for element in neu1_score_list]
Recall_Precision_Cal(neu1_predicted_list, ground_truth_list, 'neutral')
# Out:
# (0.7251, 0.2516)

# %%
print('Number of Positive: ' + str(neu1_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neu1_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neu1_predicted_list.count('negative')))
# Out:
# Number of Positive: 1455
# Number of Neutral: 1824
# Number of Negative: 323

# %% [markdown]
# ### Neutral Rule #2 (if the sentence contains some neutral words, then sentiment of aspect terms will become neutral)

# %%
# Create a neutral word list
neutral_word_list = ['ok','neutral', 'average', 'okay', 'fair']

# additional score for having above positive words (most of them are non-adjective and have zero score under Textblob)
neutral_rule_2_score_add = []
for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    neutral_score = 1
    for j in range(len(data_dict[i]['term'])):
        if(data_dict[i]['polarity'][j]!='conflict'):
            for k in range(len(neutral_word_list)):
                if sentence.split().count(neutral_word_list[k]):
                    neutral_score = 0
            neutral_rule_2_score_add.append(neutral_score)
        

zipped_lists = zip(neu1_score_list, neutral_rule_2_score_add)
neu2_score_list = [x * y for (x, y) in zipped_lists]
neu2_predicted_list = [polarity_define(element) for element in neu2_score_list]
Recall_Precision_Cal(neu2_predicted_list, ground_truth_list, 'neutral')
# Out:
# (0.7393, 0.2515)

# %%
print('Number of Positive: ' + str(neu2_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neu2_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neu2_predicted_list.count('negative')))
# Out:
# Number of Positive: 1435
# Number of Neutral: 1861
# Number of Negative: 306

# %% [markdown]
# ### Neutral Rule #3 (Collect 2 words around aspect terms, and use them to predict sentiment)

# %%
neutral_rule_3_part_sentence = []
for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    for j in range(len(data_dict[i]['term'])):
        part_sentence = []
        if(data_dict[i]['polarity'][j]!='conflict'):
            try:
                index = sentence.split().index(str(data_dict[i]['term'][j]))
                for k in range(index - 1, index + 1, 1):
                    if k >= 0 and k < len(sentence.split()):
                        part_sentence.append(sentence.split()[k])
            except:
                part_sentence.append('')
        
        text = ' '.join(part_sentence)
        neutral_rule_3_part_sentence.append(text)
          
neutral_rule_3_score_add = [TextBlob(str(element)).sentiment.polarity for element in neutral_rule_3_part_sentence]

neutral_rule_3_score = []
for i in range(len(neu1_score_list)):
    if neu1_score_list[i] ==0:
        neutral_rule_3_score.append(neu1_score_list[i] + neutral_rule_3_score_add[i])
    else:
        neutral_rule_3_score.append(neu1_score_list[i])
            
neu3_predicted_list = [polarity_define(element) for element in neutral_rule_3_score]
Recall_Precision_Cal(neu3_predicted_list, ground_truth_list, 'neutral')
# Out:
# (0.5624, 0.25)

# %%
print('Number of Positive: ' + str(neu3_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neu3_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neu3_predicted_list.count('negative')))
# Out:
# Number of Positive: 1788
# Number of Neutral: 1424
# Number of Negative: 390

# %% [markdown]
# ### Negative Rule #1 (General Rule)

# %%
adjective_list = []
num = 0

for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    sen = nlp(sentence)
    for j in range(len(data_dict[i]['term'])):
        if(data_dict[i]['polarity'][j]!='conflict'):
            num += 1
            for token in sen:
                if str(token) == data_dict[i]['term'][j]:
                    head = token.head
                    children = [child for child in token.children]
            
            
            # Use aspect term's Head as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                            adjective_list.append(token)
                            
                            
            # Use aspect term's children as an adjective
            if(num > len(adjective_list)):
                for child in children:
                    for token in sen:
                        if(num > len(adjective_list)):
                            if(str(token)==str(child)):
                                if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                    adjective_list.append(token)
                                    break
            
            # Use aspect term's Head's children as an adjective
            if(num > len(adjective_list)):
                for token in sen:
                    if str(token) == str(head):
                        head_children = [child for child in token.children]

                        for child in head_children:
                            for token in sen:
                                if(num > len(adjective_list)):
                                    if(str(token)==str(child)):
                                        if token.dep_ == 'amod' or token.dep_ =='acomp' or token.dep_=='advmod' or token.pos_ =='ADJ':
                                            adjective_list.append(token)
                                            break
            
                                                                                     
            # Find the adjective near the aspect term in sentence as adjective
            if(num > len(adjective_list)):
                fufill = False
                try:
                    index = sentence.split().index(str(data_dict[i]['term'][j]))
                    for k in range(index - 4, index + 4, 1):
                        if k >= 0 and k < len(sentence.split()):
                            if fufill == False:
                                if sen[k].dep =='amod' or sen[k].dep_ =='acomp' or sen[k].dep_=='advmod' or sen[k].pos_ == 'ADJ':
                                    adjective_list.append(sen[k])
                                    fufill = True
                except:
                    None
            
            # Others are treated it as Neutral
            if(num > len(adjective_list)):
                adjective_list.append('neutral')
                
neg1_score_list = [TextBlob(str(element)).sentiment.polarity for element in adjective_list]
neg1_predicted_list = [polarity_define(element) for element in neg1_score_list]
Recall_Precision_Cal(neg1_predicted_list, ground_truth_list, 'negative')
# Out:
# (0.2398, 0.5975)

# %%
print('Number of Positive: ' + str(neg1_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neg1_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neg1_predicted_list.count('negative')))
# Out:
# Number of Positive: 1455
# Number of Neutral: 1824
# Number of Negative: 323

# %% [markdown]
# ### Negative Rule #2  (if the sentence contains some negative words, then sentiment of aspect terms will become negative)

# %%
# Create a negative word list (polarity score of below words are zero under textblov=b)
negative_word_list = ['worst', 'waterbug', 'waterbugs', 'concern','limited', 'crowded', 'forget', 'forgot','sticky', 'overpriced', 'salty', 'skipped', 'skip', 'overcooked', 'undercooked', 'oily']

# additional score for having above negative words (all of them have zero score under Textblob)
neg_rule_1_score_add = []
for i in range(len(data_dict)):
    sentence = data_dict[i]['text']
    add_score = 0
    for j in range(len(data_dict[i]['term'])):
        for k in range(len(negative_word_list)):
            if sentence.split().count(negative_word_list[k]):
                add_score -= 0.1
        neg_rule_1_score_add.append(add_score)
        

zipped_lists = zip(neg1_score_list, neg_rule_1_score_add)
neg2_score_list = [x + y for (x, y) in zipped_lists]
neg2_predicted_list = [polarity_define(element) for element in neg2_score_list]
Recall_Precision_Cal(neg2_predicted_list, ground_truth_list, 'negative')
# Out:
# (0.2683, 0.532)

# %%
print('Number of Positive: ' + str(neg2_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neg2_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neg2_predicted_list.count('negative')))
# Out:
# Number of Positive: 1445
# Number of Neutral: 1751
# Number of Negative: 406

# %% [markdown]
# ### Negative Rule 3 (Negate words around negative words)

# %%
num = -1
negate_list = []
for i in range(len(data_dict)):
    sentence = original_data_dict[i]['text']
    sen = nlp(sentence)
    for j in range(len(data_dict[i]['term'])):
        negate_flag = 0
        if(data_dict[i]['polarity'][j]!='conflict'):
            num += 1
            
            # detect if the adjective is a positive word or a neutral word
            if TextBlob(str(adjective_list[num])).sentiment.polarity >= 0:
                try:
                    index = sentence.split().index(str(adjective_list[num]))
                    for k in range(index- 5, index + 5 , 1):
                        if k >= 0 and k < len(sentence.split()):
                            if sen[k].dep_=='neg': 
                                negate_flag = -1
                except:
                    None
                
                negate_list.append(negate_flag)
            else:
                
                negate_list.append(negate_flag)
                
zipped_lists = zip(neg2_score_list, negate_list)
neg3_score_list = [x + y for (x, y) in zipped_lists]
neg3_predicted_list = [polarity_define(element) for element in neg3_score_list]
Recall_Precision_Cal(neg3_predicted_list, ground_truth_list, 'negative')
# Out:
# (0.3429, 0.5227)

# %%
print('Number of Positive: ' + str(neg3_predicted_list.count('positive')))
print('Number of Neutral: ' + str(neg3_predicted_list.count('neutral')))
print('Number of Negative: ' + str(neg3_predicted_list.count('negative')))
# Out:
# Number of Positive: 1382
# Number of Neutral: 1692
# Number of Negative: 528

# %% [markdown]
# ## Example

# %%
sentence = data_dict[0]['text']
sentence = remove_stopwords("The design and atmosphere is just as good.")

sen = nlp(sentence)

# title head
print ("{:<13} | {:<9} | {:<9} |{:<13} | {:<22}".format('Token','Relation', 'Pos', 'Head', 'Children'))
print ("-" * 70)

for token in sen:
    # Print the token, relation dependency, part of speech, head and all dependents of the token
    print ("{:<13} | {:<9} | {:<9} | {:<13} | {:<22}"
         .format(str(token.text), str(token.dep_), str(token.pos_), str(token.head.text), str([child for child in token.children])))
  
# Display the graph
displacy.render(sen, style='dep', jupyter=True, options={'distance': 110})
# Out:
# Token         | Relation  | Pos       |Head          | Children
# ----------------------------------------------------------------------
# The           | det       | DET       | atmosphere    | []
# design        | compound  | NOUN      | atmosphere    | []
# atmosphere    | nsubj     | NOUN      | good          | [The, design]
# good          | ROOT      | ADJ       | good          | [atmosphere, .]
# .             | punct     | PUNCT     | good          | []
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f1510515f4bd4a0f950ace8ac538cdce-0" class="displacy" width="490" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">design</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">atmosphere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">good .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f1510515f4bd4a0f950ace8ac538cdce-0-0" stroke-width="2px" d="M70,112.0 C70,2.0 270.0,2.0 270.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f1510515f4bd4a0f950ace8ac538cdce-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L62,102.0 78,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f1510515f4bd4a0f950ace8ac538cdce-0-1" stroke-width="2px" d="M180,112.0 C180,57.0 265.0,57.0 265.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f1510515f4bd4a0f950ace8ac538cdce-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,114.0 L172,102.0 188,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f1510515f4bd4a0f950ace8ac538cdce-0-2" stroke-width="2px" d="M290,112.0 C290,57.0 375.0,57.0 375.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f1510515f4bd4a0f950ace8ac538cdce-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,114.0 L282,102.0 298,102.0" fill="currentColor"/>
# </g>
# </svg></span>
